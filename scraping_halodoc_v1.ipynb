# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Scraping No.1**
# > 01 - 10 categories

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "covid-19"

page=4
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_covid = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                   "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                   "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                   "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "halofit"

page=2
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_halofit1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                            "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                            "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                            "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "halofit"

page=3
for i in range(2,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_halofit2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                            "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                            "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                            "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "halofit"

page=3
for i in range(2,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_halofit2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                            "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                            "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                            "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "saluran-kemih-dan-prostat"

page=3
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_saluranKemih = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "diet"

page=2
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_diet = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "penawaran-special"

page=1
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_penawaranSpesial1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                    "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                    "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                    "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "penawaran-special"

page=2
for i in range(1,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_penawaranSpesial2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                    "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                    "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                    "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "anti-virus"

page=3
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_antiVirus = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                    "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                    "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                    "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "hearing-aids"

page=2
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_alatDengar1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                    "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                    "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                    "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "hearing-aids"

page=3
for i in range(2,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_alatDengar2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                    "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                    "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                    "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "sehat-hemat"

page=4
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_sehatHemat = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                    "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                    "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                    "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "healthy-lifestyle"

page=6
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_healthyLifestyle = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                    "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                    "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                    "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_covid
# df_halofit1
# df_halofit2
# df_saluranKemih
# df_diet
# df_penawaranSpesial1
# df_penawaranSpesial2
# df_antiVirus
# df_alatDengar1
# df_alatDengar2
# df_sehatHemat
df_healthyLifestyle.head(2)
# Out:
#                                      Nama  min_price  base_price selling_unit  \
# 0              Twinlab Zma Fuel 90 Kapsul     615600      615600    Per Botol
# 1  Universal Ultra Iso Whey Chocolate 2Lb    1269300     1438400    Per Botol
#
#            packaging                                           kategori  \
# 0  Botol @ 90 Kapsul  [{'external_id': 'd01e4664-18f2-4853-9924-bdf7...
# 1      Botol @ 908 g  [{'external_id': 'd01e4664-18f2-4853-9924-bdf7...
#
#   deskripsi                                      indikasi_umum  \
# 0            Suplemen yang sangat berfungsi dalam meningkat...
# 1            Supplement susu protein pada setiap gramnya me...
#
#                                            komposisi  \
# 0  Protein, Vitamin B6 (as pyridoxine hydrochlori...
# 1                                       WHEY PROTEIN
#
#                                                dosis  \
# 0                         2 - 3 tablet sebelum tidur
# ...

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "batuk-dan-flu"

page=10
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_batuk1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "batuk-dan-flu"

page=20
for i in range(11,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_batuk2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "batuk-dan-flu"

page=30
for i in range(21,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_batuk3 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "batuk-dan-flu"

page=31
for i in range(30,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(selling_unit)
          # print(packaging)
          # print(deskripsi)
          # print(indikasi_umum)
          # print(komposisi)
          # print(dosis)
          # print(aturan_pakai)
          # print(kontra_indikasi)
          # print(perhatian)
          # print(efek_samping)
          # print(segmentasi)
          # print(manufaktur)
          # print(no_registrasi)
          # print(slug)
          # print(productID)
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_batuk4 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
df_batuk4.head()
# Out:
#                            Nama  min_price  base_price selling_unit  \
# 0     Termorex Plus Sirup 60 ml      10700       22500    Per Botol
# 1       Ternix Plus Sirup 60 ml       9100       18300    Per Botol
# 2            Ternix Sirup 60 ml       7800       18000    Per Botol
# 3            Tranabat 10 Tablet       5900       11500    Per Strip
# 4  Transbroncho 30 mg 10 Tablet       8900       20000    Per Strip
#
#                              packaging  \
# 0           Dus, Botol Plastik @ 60 ml
# 1                   Dus, Botol @ 60 ml
# 2                   Dut, Botol @ 60 ml
# 3  Dus, 10 Amplop, 1 Strip @ 10 Tablet
# 4            Dus, 10 Strip @ 10 Tablet
#
#                                             kategori  \
# 0  [{'external_id': 'a883b8f3-dae3-4903-b786-8d80...
# 1  [{'external_id': 'a883b8f3-dae3-4903-b786-8d80...
# 2  [{'external_id': 'a883b8f3-dae3-4903-b786-8d80...
# 3  [{'external_id': 'a883b8f3-dae3-4903-b786-8d80...
# ...

# %%
frames = [df_covid, df_halofit1, df_halofit2,df_saluranKemih,df_diet,\
         df_penawaranSpesial1,df_penawaranSpesial2,df_antiVirus,df_alatDengar1,\
         df_alatDengar2,df_sehatHemat,df_healthyLifestyle,df_batuk1,df_batuk2,\
         df_batuk3,df_batuk4]
result10 = pd.concat(frames)

# %%
result10
# Out:
#                                                  Nama  min_price  base_price  \
# 0          For-D3 Vitamin D3 1000 IU 10 Tablet Kunyah      25900       36000
# 1                            Imboost Kids Sirup 45 ml      27800       35000
# 2                          Ivermectin 12 mg 20 Tablet     149800      165000
# 3   Ivermectin 12 mg 20 Tablet + INAmask Surgical ...     175000      210000
# 4   Ivermectin 12 mg 20 Tablet + INAmask Surgical ...     180000      191100
# ..                                                ...        ...         ...
# 10                                Unidryl Sirup 60 ml       3400        5000
# 11                              Valved Dm Sirup 60 ml      25000       25300
# 12                                       Vipcol 60 ml       7400       16400
# 13                                Vostrin Sirup 60 ml      34300       63000
# 14                                   Zentra 10 Kaplet      11400       15000
#
# ...

# %%
# export batukflu1
# result10.to_excel('crawling_scraping10.xlsx', index=False)

# %% [markdown]
# <br>

# %% [markdown]
# --------------------------

# %% [markdown]
# ## **Scraping No.2**
# > 10 - 20 categories

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "anti-inflamasi"

page=4
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_antiInflamasi1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                 "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                 "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                 "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "anti-inflamasi"

page=6
for i in range(5,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_antiInflamasi2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                 "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                 "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                 "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "beauty-enhancer"

page=5
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_beautyEnhancer1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                   "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                   "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                   "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "beauty-enhancer"

page=7
for i in range(6,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_beautyEnhancer2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                   "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                   "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                   "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "asma"

page=5
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_asma1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "asma"

page=7
for i in range(6,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_asma2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "antiseptik"

page=6
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_antiseptik1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "antiseptik"

page=8
for i in range(6,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_antiseptik2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "alergi"

page=8
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_alergi1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "alergi"

page=9
for i in range(8,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_alergi2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "mulut-dan-tenggorokan"

page=8
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_mulut1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "mulut-dan-tenggorokan"

page=9
for i in range(8,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_mulut2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "demam"

page=8
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_demam1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "demam"

page=9
for i in range(8,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_demam2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "derma-skin"

page=10
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_derma1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "derma-skin"

page=11
for i in range(10,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_derma2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "kontrasepsi-dan-hormon"

page=10
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_kontra1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "kontrasepsi-dan-hormon"

page=11
for i in range(10,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_kontra2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "p3k"

page=10
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_p3k1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "p3k"

page=12
for i in range(10,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_p3k2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                         "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                         "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                         "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_antiInflamasi1
# df_antiInflamasi2
# df_beautyEnhancer1
# df_beautyEnhancer2
# df_asma1
# df_asma2
# df_antiseptik1
# df_antiseptik2
# df_alergi1
# df_alergi2
# df_mulut1
# df_mulut2
# df_demam1
# df_demam2
# df_derma1
# df_derma2
# df_kontra1
# df_kontra2
# df_p3k1
df_p3k2
# Out:
#                       Nama  min_price  base_price selling_unit packaging  \
# 0      Wundres F Pink 5X20     188100      225500     Per Pack
# 1       Wundres F Pink 5X5     112000      112000     Per Pack
# 2   Wundres N Kuning 10X10      85800      107100     Per Pack
# 3  Wundresing App 10X15 cm      21500       21500    Per Piece
# 4      Wundres F Pink 5X20     188100      225500     Per Pack
# 5       Wundres F Pink 5X5     112000      112000     Per Pack
# 6   Wundres N Kuning 10X10      85800      107100     Per Pack
# 7  Wundresing App 10X15 cm      21500       21500    Per Piece
#
#                                             kategori deskripsi  \
# 0  [{'external_id': '5f20843e-010f-4361-9f35-51e8...
# 1  [{'external_id': '5f20843e-010f-4361-9f35-51e8...
# 2  [{'external_id': '5f20843e-010f-4361-9f35-51e8...
# 3  [{'external_id': '5f20843e-010f-4361-9f35-51e8...
# 4  [{'external_id': '5f20843e-010f-4361-9f35-51e8...
# 5  [{'external_id': '5f20843e-010f-4361-9f35-51e8...
# ...

# %%
frames = [df_antiInflamasi1,df_antiInflamasi2,df_beautyEnhancer1,
          df_beautyEnhancer2,df_asma1,df_asma2,df_antiseptik1,df_antiseptik2,df_alergi1,df_alergi2,
          df_mulut1,df_mulut2,df_demam1,df_demam2,df_derma1,df_derma2,df_kontra1,df_kontra2,df_p3k1,
          df_p3k2]

result20 = pd.concat(frames)

# %%
result20
# Out:
#                                  Nama  min_price  base_price selling_unit  \
# 0                    Exabet 10 Tablet      12000       23800    Per Strip
# 1          Faridexon 0.5 mg 10 Kaplet       1200        5200    Per Strip
# 2   Faridexon Forte 0.75 mg 10 Kaplet       1100        7800    Per Strip
# 3               Flason 8 mg 10 Tablet      36500       40000    Per Strip
# 4           Gamesolone 4 mg 10 Tablet      13500       36000    Per Strip
# ..                                ...        ...         ...          ...
# 3             Wundresing App 10X15 cm      21500       21500    Per Piece
# 4                 Wundres F Pink 5X20     188100      225500     Per Pack
# 5                  Wundres F Pink 5X5     112000      112000     Per Pack
# 6              Wundres N Kuning 10X10      85800      107100     Per Pack
# 7             Wundresing App 10X15 cm      21500       21500    Per Piece
#
#                           packaging  \
# 0         Dus, 10 Strip @ 10 Tablet
# ...

# %%
# export batukflu1
# result20.to_excel('crawling_scraping20.xlsx', index=False)
