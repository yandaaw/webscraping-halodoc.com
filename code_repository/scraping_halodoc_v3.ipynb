# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Scraping No.5**
# > 30 - 40 categories <br>
# > **Susu dab Antibiotik**

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "produk-susu"

page=20
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_susu1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}


page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "produk-susu"

page=40
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_susu2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_susu1
df_susu2
# Out:
#                                                   Nama  min_price  base_price  \
# 0                     Vidoran Xmart 3+ Milk Madu 350 g      18500       37400
# 1                     Vidoran Xmart 3+ Milk Madu 725 g      43800       75600
# 2                     Vidoran Xmart 3+ Milk Madu 950 g      59400       72700
# 3                   Vidoran Xmart 3+ Milk Vanila 350 g      24200       35200
# 4                   Vidoran Xmart 3+ Milk Vanila 725 g      44300       75600
# ..                                                 ...        ...         ...
# 395  WRP Lose Weight Meal Replacement Green Tea 12 ...     106400      106400
# 396  WRP Lose Weight Meal Replacement Strawberry 12...     103700      108900
# 397                     WRP On The Go Strawbrry 200 ml      13000       15100
# 398                     WRP On To Go Chocolate 2X200ml      18100       26000
# 399                               Zee Honey Milk 350 g      37800       53900
#
#     selling_unit                    packaging  \
# 0        Per Box                    Box 375 g
# 1        Per Box  Box, Aluminium foil @ 725 g
# 2      Per Botol            Box, Botol 1000 g
# 3        Per Box                    Box 375 g
# 4        Per Box                    Box 725 g
# ..           ...                          ...
# 395      Per Box        Dus, 12 Sachet @ 25 G
# 396      Per Box        Dus, 12 Sachet @ 25 G
# 397      Per Box        Karton Laminat 200 ml
# 398     Per Pack
# 399      Per Box                    Box 350 g
#
#                                               kategori deskripsi  \
# 0    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# 1    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# 2    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# 3    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# 4    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# ..                                                 ...       ...
# 395  [{'external_id': 'a7a2bb3c-6dec-47b7-9396-cfbb...
# 396  [{'external_id': 'a7a2bb3c-6dec-47b7-9396-cfbb...
# 397  [{'external_id': 'a7a2bb3c-6dec-47b7-9396-cfbb...
# 398  [{'external_id': 'a7a2bb3c-6dec-47b7-9396-cfbb...
# 399  [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
#
#                                          indikasi_umum  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 395  Susu pengganti makan untuk menurunkan berat ba...
# 396  Susu pengganti makan untuk menurunkan berat ba...
# 397
# 398
# 399
#
#                                              komposisi dosis  \
# 0
# 1
# 2                                                        NaN
# 3
# 4
# ..                                                 ...   ...
# 395  Susu bubuk skim, susu bubuk full krim, gula, p...
# 396  Susu bubuk skim, susu bubuk full krim, gula, p...
# 397                                                      NaN
# 398                                                      NaN
# 399
#
#                                           aturan_pakai kontra_indikasi  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...             ...
# 395  Campurkan 2 sachet WRP Meal Replacement dalam ...
# 396  Campurkan 2 sachet WRP Meal Replacement dalam ...
# 397
# 398
# 399
#
#     perhatian efek_samping         segmentasi           manufaktur  \
# 0                           (Consumer Goods,)   Tempo Scan Pacific
# 1                           (Consumer Goods,)   Tempo Scan Pacific
# 2                           (Consumer Goods,)   Tempo Scan Pacific
# 3                           (Consumer Goods,)   Tempo Scan Pacific
# 4                           (Consumer Goods,)   Tempo Scan Pacific
# ..        ...          ...                ...                  ...
# 395                         (Consumer Goods,)  Nutrifood Indonesia
# 396                         (Consumer Goods,)  Nutrifood Indonesia
# 397                         (Consumer Goods,)  Nutrifood Indonesia
# 398                         (Consumer Goods,)  Nutrifood Indonesia
# 399                         (Consumer Goods,)    Sanghiang Perkasa
#
#     no_registrasi                                               slug  \
# 0                                    vidoran-xmart-3-milk-madu-350-g
# 1                                    vidoran-xmart-3-milk-madu-725-g
# 2                                    vidoran-xmart-3-milk-madu-950-g
# 3                                  vidoran-xmart-3-milk-vanila-350-g
# 4                                  vidoran-xmart-3-milk-vanila-725-g
# ..            ...                                                ...
# 395                wrp-lose-weight-meal-replacement-green-tea-12-...
# 396                wrp-lose-weight-meal-replacement-strawberry-12...
# 397                                   wrp-on-the-go-strawbrry-200-ml
# 398                                   wrp-on-to-go-chocolate-2x200ml
# 399                                             zee-honey-milk-350-g
#
#                                 ProductID
# 0    94468eef-81c6-4497-8b7e-8185b6bdd5b9
# 1    938cb997-8a23-459a-b9fd-03000dda77af
# 2    e1fc0533-2647-4c1d-9d92-8f1749fde815
# 3    0cfce11a-a6c9-4eaf-ba84-84332860ed9b
# 4    5c021b41-87f2-47c8-8337-19d1a8374e6a
# ..                                    ...
# 395  77710d26-98fe-42a9-8242-98108c791b8c
# 396  b418b1af-e413-4f46-9f24-5175c4b603f6
# 397  14187f41-96d3-429c-a554-7c3456157bcf
# 398  f78d247d-de45-4b9a-bf5c-7fd0a5aaabf9
# 399  0f3acb60-d7d6-4561-9c0f-3b462ef41a96
#
# [400 rows x 19 columns]

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}


page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "antibiotik-dan-anti-jamur"

page=20
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_antibiotik1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}


page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "antibiotik-dan-anti-jamur"

page=34
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_antibiotik2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_antibiotik1
df_antibiotik2
# Out:
#                                   Nama  min_price  base_price selling_unit  \
# 0    Topcillin 125 mg/5 ml Sirup 60 ml      11900       18400    Per Botol
# 1    Topcillin 250 mg/5 ml Sirup 60 ml      15000       35000    Per Botol
# 2           Topcillin 500 mg 10 Kaplet       6500       18600    Per Strip
# 3                       Trachon Kapsul      16500       30000   Per Kapsul
# 4               Trichodazol Plus Ovula      16300       30000    Per Piece
# ..                                 ...        ...         ...          ...
# 275                  Vibranat 6 Kaplet     111600      121700    Per Strip
# 276            Viflox 500 mg 10 Tablet     139500      237800    Per Strip
# 277           Vioquin 500 mg 10 Kaplet      99800      198100    Per Strip
# 278            Vocefa 500 mg 10 Kapsul      98200      149700    Per Strip
# 279           Vocefa Forte Sirup 60 ml      76100      109300    Per Botol
#
#                                packaging  \
# 0                     Dus, Botol @ 60 ml
# 1                     Dus, Botol @ 60 ml
# 2              Kaplet 500 Mg X 10 X 10\n
# 3                 Kapsul 100 Mg X 1 X 10
# 4                           ovula x 6 x1
# ..                                   ...
# 275  Dus, 5 Strip @ Kaplet Salut Selaput
# 276                   Tablet 500 Mg X 50
# 277             Kaplet 500 Mg X 3 X 10\n
# 278               Kapsul 500 Mg X 3 X 10
# 279                   Dus, Botol @ 60 ml
#
#                                               kategori deskripsi  \
# 0    [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 1    [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 2    [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 3    [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...
# 4    [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# ..                                                 ...       ...
# 275  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 276  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 277  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 278  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 279  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
#
#                                          indikasi_umum  \
# 0    Infeksi saluran napas atas dan bawah, infeksi ...
# 1    Infeksi kuman Garam negatif dan positif pada s...
# 2    Infeksi kuman Garam negatif dan positif pada s...
# 3    Kandidosis Vulvovaginal, Pitiriasis Versikolor...
# 4    Infeksi vagina yang disebabkan Trichomonas vag...
# ..                                                 ...
# 275  Infeksi di saluran pernfasan bagian atas & baw...
# 276  Sinusitis maksilaris akut, eksaserbasi akut da...
# 277  Infeksi karena bakteri yang peka terhadap sipr...
# 278  Infeksi sal nafas; tonsilitis, faringitis, bro...
# 279  Infeksi sal nafas; tonsilitis, faringitis, bro...
#
#                                              komposisi  \
# 0    Per 5 mL : Amoxicillin 125 mg, asam klavulanat...
# 1    Tiap 5 ml mengandung 250 mg Amoxicillin trihyd...
# 2                        Amoxicillin trihydrate 500 mg
# 3                                  Itraconazole 100 mg
# 4                                 Metronidazole 500 mg
# ..                                                 ...
# 275  Co-amoxiclav : Amoxicillin 500 mg, clavulanic ...
# 276                               Ciprofloxacin 500 mg
# 277                           Ciprofloxacin HCI 500 mg
# 278                      Cefadroxil monohydrate 500 mg
# 279           Per 5 mL : Cefadroxil monohydrate 250 mg
#
#                                                  dosis  \
# 0    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 1    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 2    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 3    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 4    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# ..                                                 ...
# 275  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 276  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 277  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 278  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 279  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
#
#                                       aturan_pakai  \
# 0                          Berikan bersama mAkanan
# 1                           Berikan bersama mkanan
# 2                         Berikan bersama mkanan\n
# 3                       Segera sesudah makan utama
# 4    Sebelum tidur, Utk dimasukkan ke dalam vagina
# ..                                             ...
# 275            Sebelum / sesudah makan, dihabiskan
# 276                        Berikan bersama makanan
# 277                        Berikan sebelum makan\n
# 278                        Berikan bersama makanan
# 279                        Berikan bersama makanan
#
#                                        kontra_indikasi  \
# 0                     Hipersensitif terhadap penisilin
# 1    Hiersensitif terhadap penisilin. Infeksi monon...
# 2    Hiersensitif terhadap penisilin. Infeksi monon...
# 3                                                Hamil
# 4                 Hipersensitivitas. Hamil trimester 1
# ..                                                 ...
# 275  Hipersensitifitas. Bayi yang lahir dari ibu ya...
# 276  Hipersensitif terhadap siprofloksasin atau kui...
# 277  Hipersensitif terhadap siprofloksasin atau der...
# 278  Penggunaan antibiotik vocefa (cefadroxil) haru...
# 279  Penggunaan antibiotik vocefa (cefadroxil) haru...
#
#                                              perhatian  \
# 0    HARUS DENGAN RESEP DOKTER. \nHipersensitif ter...
# 1    HARUS DENGAN RESEP DOKTER. \nHipersensitif ter...
# 2    HARUS DENGAN RESEP DOKTER. \nHipersensitif ter...
# 3    HARUS DENGAN RESEP DOKTER. \nLaktasi, riwayat ...
# 4    HARUS DENGAN RESEP DOKTER. \nPengobatan dihent...
# ..                                                 ...
# 275  HARUS DENGAN RESEP DOKTER. \nPenyakit hati ber...
# 276  HARUS DENGAN RESEP DOKTER. \nEpilepsi, kerusak...
# 277  HARUS DENGAN RESEP DOKTER. \nKerusakan ginjal,...
# 278  HARUS DENGAN RESEP DOKTER. \nDiketahui alergi ...
# 279  HARUS DENGAN RESEP DOKTER. \nDiketahui alergi ...
#
#                                           efek_samping segmentasi  \
# 0    Gangguan Gl, reaksi alergi, anafilaksis, kelai...     (Red,)
# 1    Gangguan Gl, reaksi alergi, anafilaksis, kelai...     (Red,)
# 2    Gangguan Gl, reaksi alergi, anafilaksis, kelai...     (Red,)
# 3              Gangguan gastrointestinal, sakit kepala     (Red,)
# 4    Reaksi hipersensitivitas, leukopenia & trombos...     (Red,)
# ..                                                 ...        ...
# 275  Urticaria, kemerahan pada kulit seperti pada c...     (Red,)
# 276  Mual, muntah, dispepsia, nyeri perut, diare, s...     (Red,)
# 277  Gangguan Gl, gangguan SSP, reaksi hipersensiti...     (Red,)
# 278  Kram dan nyeri perut, mual, muntah, diare, rea...     (Red,)
# 279  Kram dan nyeri perut, mual, muntah, diare, rea...     (Red,)
#
#                      manufaktur          no_registrasi  \
# 0                  Dankos Farma  BPOM: DKL7804426838A1
# 1                  Dankos Farma  BPOM: DKL8504401438B1
# 2                  Dankos Farma  BPOM: DKL8504401404A1
# 3                     Bernofarm  BPOM: DKL9902328301A1
# 4                   Sanbe Farma  BPOM: DKL0522241750A1
# ..                          ...                    ...
# 275                     Pyridam  BPOM: DKL1021016009A2
# 276  Tropica Mas Pharmaceutical  BPOM: DKL0226007409A1
# 277            Gracia Pharmindo  BPOM: DKL0435300709A1
# 278            Gracia Pharmindo  BPOM: DKL0535302901A1
# 279            Gracia Pharmindo  BPOM: DKL0535303038B1
#
#                                   slug                             ProductID
# 0    topcillin-125-mg-5-ml-sirup-60-ml  d775ec74-e2fa-46c8-80e6-35dde8d6b05e
# 1    topcillin-250-mg-5-ml-sirup-60-ml  a2b38b5f-4adf-4c7d-85c1-eb6db8eb0722
# 2           topcillin-500-mg-10-kaplet  28a47bc0-73f8-44a4-9c5c-07d516e3e375
# 3                       trachon-kapsul  091199f8-081f-40b6-a8ed-dc43f2d0b624
# 4               trichodazol-plus-ovula  36d0c142-e756-4aa7-991b-84093499ae03
# ..                                 ...                                   ...
# 275                  vibranat-6-kaplet  2914d43a-2531-4ca8-b824-3e3a470f1f4e
# 276            viflox-500-mg-10-tablet  f743cf56-fd19-486b-8a43-3886a4439fb7
# 277           vioquin-500-mg-10-kaplet  3ba03e94-fd83-4cbf-a663-7db7006b21a7
# 278            vocefa-500-mg-10-kapsul  5c07da72-ca61-4c75-93b1-3a09a656b8a5
# 279           vocefa-forte-sirup-60-ml  96f104b8-8dff-4d73-a492-73a856cbb73e
#
# [280 rows x 19 columns]

# %%
frames = [df_susu1,df_susu2,df_antibiotik1,df_antibiotik2]
        
result40_susuAntibiotik = pd.concat(frames)

# %%
result40_susuAntibiotik
# Out:
#                                             Nama  min_price  base_price  \
# 0     Frisian Flag Kental Manis Cocopandan 370 g      12100       13800
# 1        Frisian Flag Kental Manis Cokelat 490 g      13800       13800
# 2    Frisian Flag Kental Manis Coklat 120 Sachet     140400      143000
# 3         Frisian Flag Kental Manis Coklat 370 g       9700       12700
# 4      Frisian Flag Kental Manis Coklat 6 Sachet       7700       12000
# ..                                           ...        ...         ...
# 275                            Vibranat 6 Kaplet     111600      121700
# 276                      Viflox 500 mg 10 Tablet     139500      237800
# 277                     Vioquin 500 mg 10 Kaplet      99800      198100
# 278                      Vocefa 500 mg 10 Kapsul      98200      149700
# 279                     Vocefa Forte Sirup 60 ml      76100      109300
#
#     selling_unit                            packaging  \
# 0     Per Kaleng                        Kaleng 370 gr
# 1     Per Kaleng                        Kaleng 490 gr
# 2     Per Karton            Karton 120 sachet @ 40 gr
# 3     Per Kaleng                       Kaleng @ 370 g
# 4       Per Pack                        Pack 6 sachet
# ..           ...                                  ...
# 275    Per Strip  Dus, 5 Strip @ Kaplet Salut Selaput
# 276    Per Strip                   Tablet 500 Mg X 50
# 277    Per Strip             Kaplet 500 Mg X 3 X 10\n
# 278    Per Strip               Kapsul 500 Mg X 3 X 10
# 279    Per Botol                   Dus, Botol @ 60 ml
#
#                                               kategori deskripsi  \
# 0    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# 1    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# 2    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# 3    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# 4    [{'external_id': '6f7282b5-8c82-4bc3-b265-0c6e...
# ..                                                 ...       ...
# 275  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 276  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 277  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 278  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
# 279  [{'external_id': '122bc3fc-6506-4f37-a267-5a1a...         -
#
#                                          indikasi_umum  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 275  Infeksi di saluran pernfasan bagian atas & baw...
# 276  Sinusitis maksilaris akut, eksaserbasi akut da...
# 277  Infeksi karena bakteri yang peka terhadap sipr...
# 278  Infeksi sal nafas; tonsilitis, faringitis, bro...
# 279  Infeksi sal nafas; tonsilitis, faringitis, bro...
#
#                                              komposisi  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 275  Co-amoxiclav : Amoxicillin 500 mg, clavulanic ...
# 276                               Ciprofloxacin 500 mg
# 277                           Ciprofloxacin HCI 500 mg
# 278                      Cefadroxil monohydrate 500 mg
# 279           Per 5 mL : Cefadroxil monohydrate 250 mg
#
#                                                  dosis  \
# 0
# 1
# 2
# 3                                                  NaN
# 4
# ..                                                 ...
# 275  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 276  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 277  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 278  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 279  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
#
#                             aturan_pakai  \
# 0
# 1
# 2
# 3
# 4
# ..                                   ...
# 275  Sebelum / sesudah makan, dihabiskan
# 276              Berikan bersama makanan
# 277              Berikan sebelum makan\n
# 278              Berikan bersama makanan
# 279              Berikan bersama makanan
#
#                                        kontra_indikasi  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 275  Hipersensitifitas. Bayi yang lahir dari ibu ya...
# 276  Hipersensitif terhadap siprofloksasin atau kui...
# 277  Hipersensitif terhadap siprofloksasin atau der...
# 278  Penggunaan antibiotik vocefa (cefadroxil) haru...
# 279  Penggunaan antibiotik vocefa (cefadroxil) haru...
#
#                                              perhatian  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 275  HARUS DENGAN RESEP DOKTER. \nPenyakit hati ber...
# 276  HARUS DENGAN RESEP DOKTER. \nEpilepsi, kerusak...
# 277  HARUS DENGAN RESEP DOKTER. \nKerusakan ginjal,...
# 278  HARUS DENGAN RESEP DOKTER. \nDiketahui alergi ...
# 279  HARUS DENGAN RESEP DOKTER. \nDiketahui alergi ...
#
#                                           efek_samping         segmentasi  \
# 0                                                       (Consumer Goods,)
# 1                                                       (Consumer Goods,)
# 2                                                       (Consumer Goods,)
# 3                                                       (Consumer Goods,)
# 4                                                       (Consumer Goods,)
# ..                                                 ...                ...
# 275  Urticaria, kemerahan pada kulit seperti pada c...             (Red,)
# 276  Mual, muntah, dispepsia, nyeri perut, diare, s...             (Red,)
# 277  Gangguan Gl, gangguan SSP, reaksi hipersensiti...             (Red,)
# 278  Kram dan nyeri perut, mual, muntah, diare, rea...             (Red,)
# 279  Kram dan nyeri perut, mual, muntah, diare, rea...             (Red,)
#
#                      manufaktur          no_registrasi  \
# 0        Frisian Flag Indonesia
# 1        Frisian Flag Indonesia
# 2        Frisian Flag Indonesia
# 3        Frisian Flag Indonesia
# 4        Frisian Flag Indonesia
# ..                          ...                    ...
# 275                     Pyridam  BPOM: DKL1021016009A2
# 276  Tropica Mas Pharmaceutical  BPOM: DKL0226007409A1
# 277            Gracia Pharmindo  BPOM: DKL0435300709A1
# 278            Gracia Pharmindo  BPOM: DKL0535302901A1
# 279            Gracia Pharmindo  BPOM: DKL0535303038B1
#
#                                             slug  \
# 0     frisian-flag-kental-manis-cocopandan-370-g
# 1        frisian-flag-kental-manis-cokelat-490-g
# 2    frisian-flag-kental-manis-coklat-120-sachet
# 3         frisian-flag-kental-manis-coklat-370-g
# 4      frisian-flag-kental-manis-coklat-6-sachet
# ..                                           ...
# 275                            vibranat-6-kaplet
# 276                      viflox-500-mg-10-tablet
# 277                     vioquin-500-mg-10-kaplet
# 278                      vocefa-500-mg-10-kapsul
# 279                     vocefa-forte-sirup-60-ml
#
#                                 ProductID
# 0    3ed033a7-0fff-4bff-9993-b5628aebde36
# 1    5c53a141-1c52-49d9-8888-a08b4288983a
# 2    383776ab-afbe-48bb-94db-9f40b00ba6e9
# 3    e0980020-bce2-4f27-8648-6cc653853791
# 4    a3412cae-61f9-4885-b329-14c9bfab330f
# ..                                    ...
# 275  2914d43a-2531-4ca8-b824-3e3a470f1f4e
# 276  f743cf56-fd19-486b-8a43-3886a4439fb7
# 277  3ba03e94-fd83-4cbf-a663-7db7006b21a7
# 278  5c07da72-ca61-4c75-93b1-3a09a656b8a5
# 279  96f104b8-8dff-4d73-a492-73a856cbb73e
#
# [1480 rows x 19 columns]

# %%
# export batukflu1
# result40_susuAntibiotik.to_excel('crawling_scraping40_susuAntibiotik.xlsx', index=False)

# %% [markdown]
# ------------------------------------

# %% [markdown]
# ## **Scraping No.5.1**
# > 30 - 40 categories

# %%
# from urllib.request import Request, urlopen
# import json
# from bs4 import BeautifulSoup
# import pandas as pd
# import requests


# categories = []
# url = "https://www.halodoc.com/obat-dan-vitamin"
# # headers = {
# #     'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
# # }

# page = urlopen(url)
# html_bytes = page.read()
# html = html_bytes.decode("utf-8")
# soup = BeautifulSoup(html, "html.parser")
# product_category = soup.findAll("img",attrs={'loading':'lazy'})
# for kategori in product_category:
#     if (len(kategori["title"])>0):
#         categories.append(kategori["title"])

# #ARRAY
# nama_obat = []
# min_harga = []
# base_harga = []
# sell_unit = []
# paking_obat = []
# kategori_obat = []
# deskripsi_obat = []
# indikasi_obat = []
# komposisi_obat = []
# dosis_obat = []
# aturan_pakai_obat = []
# kontra_indikasi_obat = []
# perhatian_obat = []
# efek_samping_obat = []
# segmentasi_obat = []
# manufaktur_obat = []
# no_registrasi_obat = []
# slug_obat = []
# id_produk = []


# infinite_looper = 1
# page = 0
# # for i in range(18,25):

# categories_url = "anti-nyeri"

# page=18
# for i in range(0,page):
#   main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
#   second_url = "/products?page=%d&size=20" % page
#   url = main_url+second_url
#   status_code = requests.get(url).status_code
#   if (status_code != 404):
#       req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
#       webpage = urlopen(req, timeout=10).read()
#       json_data = webpage.decode('utf-8')
#       full_data = json.loads(json_data)
#       result = full_data["result"]
      
#       obatlist = []
#       for i in range (0,len(result)):
#           slug = result[i]["slug"]
#           new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
#           new_url_slug = new_url+slug
#           request=urlopen(new_url_slug)
#           json_data = request.read().decode('utf-8')
#           full_data = json.loads(json_data)

#           nama = full_data["name"]
#           if 'base_price' in full_data:
#               min_price = full_data["min_price"]
#           else:
#               min_price = "NaN"
#           if 'base_price' in full_data:
#               base_price = full_data["base_price"]
#           else:
#               base_price = "NaN"
#           if 'selling_unit' in full_data:
#               selling_unit = full_data["selling_unit"]
#           else:
#               selling_unit = "NaN"
#           if 'packaging' in full_data:
#               packaging = full_data["packaging"]
#           else:
#               packaging = "NaN"
#           if 'description' in full_data:
#             deskripsi = full_data["description"]
#           else:
#             deskripsi = "NaN"
#           if 'general_indication' in full_data:
#               indikasi_umum = full_data["general_indication"]
#           else:
#               indikasi_umum = "NaN"
#           if 'composition' in full_data:
#               komposisi = full_data["composition"]
#           else:
#               komposisi = "NaN"
#           if 'dosage' in full_data:
#               dosis = full_data["dosage"]
#           else:
#               dosis = "NaN"
#           if 'how_to_use' in full_data:
#               aturan_pakai = full_data["how_to_use"]
#           else:
#               aturan_pakai = "NaN"
#           if 'contraindication' in full_data:
#               kontra_indikasi = full_data["contraindication"]
#           else:
#               kontra_indikasi = "NaN"
#           if 'warning' in full_data:
#               perhatian = full_data["warning"]
#           else:
#               perhatian = "NaN"
#           if 'side_effects' in full_data:
#               efek_samping = full_data["side_effects"]
#           else:
#               efek_samping = "NaN"
#           if 'segmentation' in full_data:
#               segmentasi = full_data["segmentation"],
#           else:
#               segmentasi = "NaN"
#           if 'manufacturer_name' in full_data:
#               manufaktur = full_data["manufacturer_name"]
#           else:
#               manufaktur = "NaN"
#           if 'bpom_number' in full_data:
#             no_registrasi = full_data["bpom_number"]
#           else:
#             no_registrasi = "NaN"

#           slug = full_data["canon_slug"]
#           productID = full_data["external_id"]
          
#           # Test Print
#           # print(i)
#           # print(nama)
#           # print(min_price)
#           # print(base_price)
#           # print(manufaktur)
          
#           kategori = full_data["categories"]
#           for i in range (0,len(kategori)):
#               kategori_produk = kategori[i]["name"]
          
#           nama_obat.append(nama)
#           min_harga.append(min_price)
#           base_harga.append(base_price)
#           sell_unit.append(selling_unit)
#           paking_obat.append(packaging)
#           kategori_obat.append(kategori)
#           deskripsi_obat.append(deskripsi)
#           indikasi_obat.append(indikasi_umum)
#           komposisi_obat.append(komposisi)
#           dosis_obat.append(dosis)
#           aturan_pakai_obat.append(aturan_pakai)
#           kontra_indikasi_obat.append(kontra_indikasi)
#           perhatian_obat.append(perhatian)
#           efek_samping_obat.append(efek_samping)
#           segmentasi_obat.append(segmentasi)
#           manufaktur_obat.append(manufaktur)
#           no_registrasi_obat.append(no_registrasi)
#           slug_obat.append(slug)
#           id_produk.append(productID)

#   else:
#       break

# df_antiNyeri1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
#                               "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
#                               "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
#                               "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# from urllib.request import Request, urlopen
# import json
# from bs4 import BeautifulSoup
# import pandas as pd
# import requests


# categories = []
# url = "https://www.halodoc.com/obat-dan-vitamin"
# headers = {
#     'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
# }

# page = urlopen(url)
# html_bytes = page.read()
# html = html_bytes.decode("utf-8")
# soup = BeautifulSoup(html, "html.parser")
# product_category = soup.findAll("img",attrs={'loading':'lazy'})
# for kategori in product_category:
#     if (len(kategori["title"])>0):
#         categories.append(kategori["title"])

# #ARRAY
# nama_obat = []
# min_harga = []
# base_harga = []
# sell_unit = []
# paking_obat = []
# kategori_obat = []
# deskripsi_obat = []
# indikasi_obat = []
# komposisi_obat = []
# dosis_obat = []
# aturan_pakai_obat = []
# kontra_indikasi_obat = []
# perhatian_obat = []
# efek_samping_obat = []
# segmentasi_obat = []
# manufaktur_obat = []
# no_registrasi_obat = []
# slug_obat = []
# id_produk = []


# infinite_looper = 1
# page = 0
# # for i in range(18,25):

# categories_url = "anti-nyeri"

# page=19
# for i in range(15,page):
#   main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
#   second_url = "/products?page=%d&size=20" % page
#   url = main_url+second_url
#   status_code = requests.get(url).status_code
#   if (status_code != 404):
#       req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
#       webpage = urlopen(req, timeout=10).read()
#       json_data = webpage.decode('utf-8')
#       full_data = json.loads(json_data)
#       result = full_data["result"]
      
#       obatlist = []
#       for i in range (0,len(result)):
#           slug = result[i]["slug"]
#           new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
#           new_url_slug = new_url+slug
#           request=urlopen(new_url_slug)
#           json_data = request.read().decode('utf-8')
#           full_data = json.loads(json_data)

#           nama = full_data["name"]
#           if 'base_price' in full_data:
#               min_price = full_data["min_price"]
#           else:
#               min_price = "NaN"
#           if 'base_price' in full_data:
#               base_price = full_data["base_price"]
#           else:
#               base_price = "NaN"
#           if 'selling_unit' in full_data:
#               selling_unit = full_data["selling_unit"]
#           else:
#               selling_unit = "NaN"
#           if 'packaging' in full_data:
#               packaging = full_data["packaging"]
#           else:
#               packaging = "NaN"
#           if 'description' in full_data:
#             deskripsi = full_data["description"]
#           else:
#             deskripsi = "NaN"
#           if 'general_indication' in full_data:
#               indikasi_umum = full_data["general_indication"]
#           else:
#               indikasi_umum = "NaN"
#           if 'composition' in full_data:
#               komposisi = full_data["composition"]
#           else:
#               komposisi = "NaN"
#           if 'dosage' in full_data:
#               dosis = full_data["dosage"]
#           else:
#               dosis = "NaN"
#           if 'how_to_use' in full_data:
#               aturan_pakai = full_data["how_to_use"]
#           else:
#               aturan_pakai = "NaN"
#           if 'contraindication' in full_data:
#               kontra_indikasi = full_data["contraindication"]
#           else:
#               kontra_indikasi = "NaN"
#           if 'warning' in full_data:
#               perhatian = full_data["warning"]
#           else:
#               perhatian = "NaN"
#           if 'side_effects' in full_data:
#               efek_samping = full_data["side_effects"]
#           else:
#               efek_samping = "NaN"
#           if 'segmentation' in full_data:
#               segmentasi = full_data["segmentation"],
#           else:
#               segmentasi = "NaN"
#           if 'manufacturer_name' in full_data:
#               manufaktur = full_data["manufacturer_name"]
#           else:
#               manufaktur = "NaN"
#           if 'bpom_number' in full_data:
#             no_registrasi = full_data["bpom_number"]
#           else:
#             no_registrasi = "NaN"

#           slug = full_data["canon_slug"]
#           productID = full_data["external_id"]
          
#           # Test Print
#           # print(i)
#           # print(nama)
#           # print(min_price)
#           # print(base_price)
#           # print(manufaktur)
          
#           kategori = full_data["categories"]
#           for i in range (0,len(kategori)):
#               kategori_produk = kategori[i]["name"]
          
#           nama_obat.append(nama)
#           min_harga.append(min_price)
#           base_harga.append(base_price)
#           sell_unit.append(selling_unit)
#           paking_obat.append(packaging)
#           kategori_obat.append(kategori)
#           deskripsi_obat.append(deskripsi)
#           indikasi_obat.append(indikasi_umum)
#           komposisi_obat.append(komposisi)
#           dosis_obat.append(dosis)
#           aturan_pakai_obat.append(aturan_pakai)
#           kontra_indikasi_obat.append(kontra_indikasi)
#           perhatian_obat.append(perhatian)
#           efek_samping_obat.append(efek_samping)
#           segmentasi_obat.append(segmentasi)
#           manufaktur_obat.append(manufaktur)
#           no_registrasi_obat.append(no_registrasi)
#           slug_obat.append(slug)
#           id_produk.append(productID)

#   else:
#       break

# df_antiNyeri2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
#                               "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
#                               "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
#                               "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_antiNyeri1
# df_antiNyeri2

# %% [markdown]
# <br>

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "alat-kesehatan"

page=10
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_alatKesehatan1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                  "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                  "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                  "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "alat-kesehatan"

page=20
for i in range(10,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_alatKesehatan2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                  "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                  "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                  "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "alat-kesehatan"

page=24
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_alatKesehatan3 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                                  "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                                  "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                                  "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_alatKesehatan1
# df_alatKesehatan2
df_alatKesehatan3
# Out:
#                                                  Nama  min_price  base_price  \
# 0     Sensi Convex Mask 4 Ply Earloop White 20 Pieces     143000      198000
# 1    Sensi Convex Mask 4 Ply Earloop Yellow 20 Pieces     161700      239400
# 2   Sensi Kids Duckbill Face Mask 3 Ply Earloop 40...     116900      220000
# 3   Sensi Kids Duckbill Face Mask 3 Ply Earloop 5 ...      12500       26400
# 4                 Sensi Kids Masker Earloop 40 Pieces     113200      159400
# ..                                                ...        ...         ...
# 75                   Stetoskop Gea Deluxe Type Sf.411      33400       68700
# 76                                    Stikpan Plastik      17300       94900
# 77                           Stomach Tube / Ngt No 12      24700       39000
# 78                    Stomach Tube / Ngt Terumo No.14      23800       39700
# 79                    Stomach Tube / Ngt Terumo No.16      22700       64800
#
#    selling_unit        packaging  \
# 0       Per Box  Box @ 20 Pieces
# 1       Per Box  Box @ 20 Pieces
# 2       Per Box  Dus @ 20 pieces
# 3      Per Pack  Pack @ 5 Pieces
# 4       Per Box  Box @ 40 Pieces
# ..          ...              ...
# 75    Per Piece    Dus @ 1 Piece
# 76    Per Piece          Plastik
# 77    Per Piece   Pack @ 1 Piece
# 78    Per Piece    Box @ 1 Piece
# 79    Per Piece   Pack Isi 1 Pcs
#
#                                              kategori  \
# 0   [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# 1   [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# 2   [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# 3   [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# 4   [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# ..                                                ...
# 75  [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# 76  [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# 77  [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# 78  [{'external_id': '385e81ca-ba12-473e-829f-45d4...
# 79  [{'external_id': '385e81ca-ba12-473e-829f-45d4...
#
#                                             deskripsi  \
# 0   SENSI CONVEX MASK adalah masker desain terbaru...
# 1   SENSI CONVEX MASK adalah masker desain terbaru...
# 2   Sensi Kids Duckbill Face Mask 3 Ply Earloop me...
# 3   Sensi Kids Duckbill Face Mask 3 Ply Earloop me...
# 4   SENSI KIDS MASKER EARLOOP merupakan masker pen...
# ..                                                ...
# 75
# 76
# 77
# 78
# 79
#
#                                         indikasi_umum     komposisi  \
# 0   Masker satu kali pakai yang dapat digunakan un...
# 1   Masker satu kali pakai yang dapat digunakan un...
# 2   Masker satu kali pakai dengan ukuran untuk ana...
# 3   Masker satu kali pakai dengan ukuran untuk ana...
# 4   Masker ini digunakan untuk melindungi saluran ...
# ..                                                ...           ...
# 75  Alat bantu pendengaran yang membantu dokter at...
# 76
# 77  Untuk nutrisi/ pemberian cairan makanan melalu...  100% silicon
# 78  Untuk nutrisi/ pemberian cairan makanan melalu...  100% silicon
# 79  Untuk nutrisi/ pemberian cairan makanan melalu...
#
#                dosis                                       aturan_pakai  \
# 0   Sesuai kebutuhan  Pasang masker hingga menutupi hidung dan mulut...
# 1   Sesuai kebutuhan  Lipat masker setengah bagian dan buka kembali....
# 2   Sesuai kebutuhan  Masker dipasangkan hingga menutupi hidung dan ...
# 3   Sesuai kebutuhan  Masker dipasangkan hingga menutupi hidung dan ...
# 4   Sesuai kebutuhan  Masker dipasangkan hingga menutupi hidung dan ...
# ..               ...                                                ...
# 75
# 76               NaN
# 77
# 78
# 79
#
#    kontra_indikasi perhatian efek_samping                      segmentasi  \
# 0                                          (Medical Device & Consumable,)
# 1                                          (Medical Device & Consumable,)
# 2                                          (Medical Device & Consumable,)
# 3                                          (Medical Device & Consumable,)
# 4                                          (Medical Device & Consumable,)
# ..             ...       ...          ...                             ...
# 75                                         (Medical Device & Consumable,)
# 76                                         (Medical Device & Consumable,)
# 77                                         (Medical Device & Consumable,)
# 78                                         (Medical Device & Consumable,)
# 79                                         (Medical Device & Consumable,)
#
#           manufaktur                no_registrasi  \
# 0     Arista Latindo  Kemenkes RI: AKD21603120139
# 1     Arista Latindo  Kemenkes RI: AKD21603120139
# 2     Arista Latindo
# 3     Arista Latindo
# 4     Arista Latindo
# ..               ...                          ...
# 75       GEA Medical                          NaN
# 76              None
# 77              None                          NaN
# 78  Terumo Indonesia                          NaN
# 79  Terumo Indonesia                          NaN
#
#                                                  slug  \
# 0   sensi-convex-mask-4-ply-earloop-white-20-pieces-2
# 1   sensi-convex-mask-4-ply-earloop-yellow-20-piec...
# 2   sensi-kids-duckbill-face-mask-3-ply-earloop-40...
# 3   sensi-kids-duckbill-face-mask-3-ply-earloop-5-...
# 4                 sensi-kids-masker-earloop-40-pieces
# ..                                                ...
# 75                   stetoskop-gea-deluxe-type-sf-411
# 76                                    stikpan-plastik
# 77                             stomach-tube-ngt-no-12
# 78                      stomach-tube-ngt-terumo-no-14
# 79                      stomach-tube-ngt-terumo-no-16
#
#                                ProductID
# 0   33a7f676-3f58-4eb9-9e8c-1c322ac48673
# 1   2c7382a9-9338-411a-ad5c-11d7be453da1
# 2   2d73e1ab-4f6d-4c90-a069-f258a97700d3
# 3   565a7b6f-a4f9-408a-be93-805ac526ade3
# 4   c9367b1a-f568-45dd-b5c4-3d149a900205
# ..                                   ...
# 75  a8293bc0-800f-4f25-9f57-2deeaf230e29
# 76  cbfd5bf5-1bfb-4b2d-9819-1e35413b8dac
# 77  92cf1ada-47af-46c8-9482-6e264cae438d
# 78  0130b3b3-3a92-40c6-add7-4f873eb6a0be
# 79  fedbc594-a70f-43a6-8d46-dc1b37114e41
#
# [80 rows x 19 columns]

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "kebutuhan-pria"

page=10
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_kebutuhan1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                              "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                              "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                              "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
df_kebutuhan1
# Out:
#                                                   Nama  min_price  base_price  \
# 0             Clear Shampoo Men Ice Cool Menthol 90 ml      10600       13800
# 1                          Cultusia Freeze Pomade 80 g          0       27700
# 2    Dayman Original Hair Pomade Pomade Strong Hold...      62500       62500
# 3           Dayman Oroginal Hair Pomade Soft Hold 45 g      41500       41500
# 4           Dayman Oroginal Hair Pomade Soft Hold 80 g      62500       62500
# ..                                                 ...        ...         ...
# 195  Garnier Men Acno Fight Wasabi Brightening Foam...      23400       38600
# 196  Garnier Men Acno Fight Wasabi Brightening Foam...      16500       28600
# 197       Garnier Men Acno Fight Whitening Serum 20 ml      18700       26400
# 198               Garnier Men Acnofight Acne Gel 10 ml      18000       30500
# 199  Garnier Men New Turbolight Oil Control Icy Scr...      20700       40700
#
#     selling_unit      packaging  \
# 0      Per Botol  Botol @ 90 ml
# 1        Per Pot  Pot @ 80 gram
# 2        Per Pot  Canister 80 g
# 3        Per Pot  Canister 45 g
# 4        Per Pot  Canister 80 g
# ..           ...            ...
# 195     Per Tube    Tube 100 ml
# 196     Per Tube     Tube 50 ml
# 197     Per Tube     Tube 20 ml
# 198     Per Tube     Tube 10 ml
# 199    Per Botol
#
#                                               kategori deskripsi  \
# 0    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 1    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 2    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 3    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 4    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# ..                                                 ...       ...
# 195  [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 196  [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 197  [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 198  [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 199  [{'external_id': '18c3b9e5-4425-404d-9368-d496...
#
#                                          indikasi_umum komposisi  \
# 0    Membersihkan kulit kepala dan rambut secara me...
# 1
# 2
# 3
# 4
# ..                                                 ...       ...
# 195
# 196
# 197
# 198
# 199
#
#                 dosis                                       aturan_pakai  \
# 0    Sesuai kebutuhan  Pijat shampo di kulit kepala Anda Bilas dan ul...
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...                                                ...
# 195  Sesuai kebutuhan
# 196  Sesuai kebutuhan
# 197  Sesuai kebutuhan
# 198               NaN
# 199
#
#     kontra_indikasi perhatian efek_samping         segmentasi  \
# 0                                           (Consumer Goods,)
# 1                                           (Consumer Goods,)
# 2                                           (Consumer Goods,)
# 3                                           (Consumer Goods,)
# 4                                           (Consumer Goods,)
# ..              ...       ...          ...                ...
# 195                                         (Consumer Goods,)
# 196                                         (Consumer Goods,)
# 197                                         (Consumer Goods,)
# 198                                         (Consumer Goods,)
# 199                                         (Consumer Goods,)
#
#              manufaktur        no_registrasi  \
# 0              Unilever                  NaN
# 1                  None
# 2    Inti Inter Pasific
# 3    Inti Inter Pasific
# 4    Inti Inter Pasific
# ..                  ...                  ...
# 195             L'Oreal                  NaN
# 196             L'Oreal                  NaN
# 197             L'Oreal  BPOM: NA18171900357
# 198   L'Oreal Indonesia
# 199             Garnier                  NaN
#
#                                                   slug  \
# 0             clear-shampoo-men-ice-cool-menthol-90-ml
# 1                          cultusia-freeze-pomade-80-g
# 2    dayman-original-hair-pomade-pomade-strong-hold...
# 3           dayman-oroginal-hair-pomade-soft-hold-45-g
# 4           dayman-oroginal-hair-pomade-soft-hold-80-g
# ..                                                 ...
# 195  garnier-men-acno-fight-wasabi-brightening-foam...
# 196  garnier-men-acno-fight-wasabi-brightening-foam...
# 197       garnier-men-acno-fight-whitening-serum-20-ml
# 198               garnier-men-acnofight-acne-gel-10-ml
# 199  garnier-men-new-turbolight-oil-control-icy-scr...
#
#                                 ProductID
# 0    98c55dda-a08b-47f3-b245-88322032520b
# 1    fc5fafc9-7a56-44cd-a541-37da1fbdb218
# 2    aee85390-d602-48d8-a48f-6c45ef9846cd
# 3    1215315a-1df6-418e-9749-cf010eef2a7c
# 4    de84b0b8-67d8-41f1-9157-68dc55a782c6
# ..                                    ...
# 195  0225653b-59c7-4784-9541-ae2f4a181c4e
# 196  13eea389-fd4c-4d8d-a603-9410ce8bc5d2
# 197  da990ef4-eee4-4247-90a4-8b3846ffed69
# 198  f6a89ba6-96e5-41bf-8de6-5d8a3971bd8b
# 199  1e57bfe5-fafb-497d-ba0f-81caa0aefcf6
#
# [200 rows x 19 columns]

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "kebutuhan-pria"

page=20
for i in range(10,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_kebutuhan2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                              "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                              "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                              "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "kebutuhan-pria"

page=23
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_kebutuhan3 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                              "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                              "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                              "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_kebutuhan2
df_kebutuhan3.head()
# Out:
#                                              Nama  min_price  base_price  \
# 0           Schick Shave Guard Wash & Shave 210 g      39900       46500
# 1                     Sea-Quill Maxtion 60 Kapsul     634800     1394000
# 2  Sebamed Balsam for Deodorant Men Roll On 50 ml     125800      155500
# 3             Sensitif Vivo Classic Thin 3 Pieces       9900       22500
# 4            Sensitif Vivo Fruity Affair 3 Pieces      10900       25000
#
#   selling_unit          packaging  \
# 0    Per Botol   Tabung dus 2.9 g
# 1    Per Botol  Botol @ 60 Kapsul
# 2    Per Botol  Roll On 50 ml X 1
# 3     Per Pack          Box 3 x 1
# 4     Per Pack     Dus @ 3 Pieces
#
#                                             kategori deskripsi  \
# 0  [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 1  [{'external_id': 'd01e4664-18f2-4853-9924-bdf7...
# 2  [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 3  [{'external_id': '0f68c9b7-7767-4337-a7db-db29...         -
# 4  [{'external_id': '0f68c9b7-7767-4337-a7db-db29...
#
#                                        indikasi_umum  \
# 0
# 1  Meningkatkan potensi seksual pada pria dan wan...
# 2  Deodorant untuk Pria berhenti bakteri yang men...
# 3  Kondom dengan pelumas.Mampu mencegah terhadap ...
# 4  Alat kontrasepsi yang digunakan oleh pasangan ...
#
#                                            komposisi  \
# 0
# 1  Echinacea 250 mg, Zn picolinate 15 mg, bee pro...
# 2  Aqua, Talc, Squalane, Caprylyl Glycol, Zinc Ri...
# 3                                       Lateks alami
# 4    Bahan terbuat dari latex alami yang berkualitas
#
#                                              dosis  \
# 0                                              NaN
# 1  Dewasa 2 kapsul 2x sehari, pagi dan malam hari.
# 2
# 3                                 Sesuai kebutuhan
# 4
#
#                                         aturan_pakai kontra_indikasi  \
# 0
# 1
# 2  Sebelum menerapkan deodoran, baik mandi atau c...
# 3  Digunakan pada organ vital pria sebelum melaku...               -
# 4  Digunakan pada organ vital pria sebelum melaku...
#
#                                            perhatian efek_samping  \
# 0
# 1
# 2
# 3  Kemasan yang sudah di buka, harus segera di pa...            -
# 4
#
#           segmentasi               manufaktur      no_registrasi  \
# 0  (Consumer Goods,)               Bima Artha
# 1          (Herbal,)     Abad Dua Satu Makmur  BPOM: TI104342211
# 2  (Consumer Goods,)               Sebapharma                NaN
# 3  (Consumer Goods,)  Steril Medica Indonesia
# 4  (Consumer Goods,)  Steril Medica Indonesia
#
#                                              slug  \
# 0         schick-shave-guard-wash-dan-shave-210-g
# 1                     sea-quill-maxtion-60-kapsul
# 2  sebamed-balsam-for-deodorant-men-roll-on-50-ml
# 3             sensitif-vivo-classic-thin-3-pieces
# 4            sensitif-vivo-fruity-affair-3-pieces
#
#                               ProductID
# 0  05f88721-ad50-4154-9d17-ba6e428c19b4
# 1  b2074b30-e118-455a-b7af-15481a94158b
# 2  71ab2dc8-a2f7-4cc0-b809-be3fb1fe70d5
# 3  cab59889-c8a0-4a11-92bc-bd372442e909
# 4  e6c032c6-05a6-4240-9718-d3bfaa1e5bba

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "kulit"

page=10
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_kulit1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                              "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                              "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                              "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "kulit"

page=20
for i in range(10,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_kulit2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                              "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                              "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                              "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "kulit"

page=26
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_kulit3 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                              "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                              "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                              "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_kulit1
# df_kulit2
df_kulit3.head()
# Out:
#                           Nama  min_price  base_price selling_unit  \
# 0  Soft U Derm Forte 20 % 40 g      29500       57000     Per Tube
# 1           Solinfec Cream 5 g       9000       26000     Per Tube
# 2    Soralen 1% Solution 15 ml      32300       79000    Per Botol
# 3             Sriti Cream 10 g       7800       44400     Per Tube
# 4         Strataderm Gel 10 gr     241000      406800     Per Tube
#
#              packaging                                           kategori  \
# 0  Tube, Krim 20 G X 1  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
# 1   Tube 5 G Dalam Dus  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
# 2          botol 15 ml  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
# 3         Tube 10 gram  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
# 4            tube 10 g  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
#
#   deskripsi                                      indikasi_umum  \
# 0            Kondisi kulit kering, iktiosis, psoriasis, der...
# 1            Infeksi jamur pada kulit : Tinea Korporis, Tin...
# 2                                                            -
# 3                                    Sebagai cream anti septic
# 4            Perawatan keloid, luka parut karena operasi, l...
#
#                     komposisi  \
# 0  Carbamide carbonyl diamide
# 1             Ketoconazole 2%
# 2              Methoxsalen 1%
# 3
# 4
#
#                                                dosis  \
# 0  Digunakan 2 kali sehari setelah mandi. Oleskan...
# 1  Oleskan tipis-tipis 1 X sehari. Infeksi resist...
# 2  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 3  Dioleskan secara tipis dan merata pada kulit y...
# 4
#
#                                         aturan_pakai  \
# 0
# 1  Krim dioleskan pada area kulit yang kulit teri...
# 2                                                  -
# 3
# 4
#
#                         kontra_indikasi  \
# 0
# 1  Hipersensitif terhadap ketokonazol\n
# 2                                     -
# 3
# 4
#
#                                            perhatian  \
# 0  Anak, hindari kontak dengan mata, membran muko...
# 1  Tidak boleh untuk mata. Anak. Hamil dan laktas...
# 2                     HARUS DENGAN RESEP DOKTER. \n-
# 3
# 4
#
#                                         efek_samping         segmentasi  \
# 0         Jarang terjadi : iritasi dan rasa terbakar  (Consumer Goods,)
# 1  Iritasi, pruritis, kulit kemerahan, rasa panas...            (Blue,)
# 2                                                  -             (Red,)
# 3                                                     (Consumer Goods,)
# 4                                                     (Consumer Goods,)
#
#                           manufaktur             no_registrasi  \
# 0                           Galenika                       NaN
# 1                              Ifars     BPOM: DTL0009211629A1
# 2  Surya Dermato Medica Laboratories     BPOM: DKL1628606041A1
# 3                               None  KEMENKES RI: 20501900605
# 4                        Stratpharma                       NaN
#
#                         slug                             ProductID
# 0  soft-u-derm-forte-20-40-g  4db73ab7-9a38-4e20-9d8d-04cbec0d5614
# 1         solinfec-cream-5-g  51a97bdc-b5b4-4b21-9b3d-d716c7504ebd
# 2   soralen-1-solution-15-ml  c94d6064-701f-4429-9ff8-15187b121f83
# 3           sriti-cream-10-g  a0c5c3d3-7670-41b3-beec-730de6d1b338
# 4       strataderm-gel-10-gr  1dd49bf4-8e2c-49a2-bab6-a9ea9184fbd5

# %%
# frames = [df_alatKesehatan1,df_alatKesehatan2,df_alatKesehatan3,
#          df_kebutuhan1]
# result40_1 = pd.concat(frames)

  
frames = [df_kebutuhan2,df_kebutuhan3,
          df_kulit1,df_kulit2,df_kulit3]

result40_1_2 = pd.concat(frames)

# %%
# result40_1
result40_1_2
# Out:
#                                                   Nama  min_price  base_price  \
# 0        Nivea Men Deodorant Fresh Active Spray 150 ml      45400       45400
# 1    Nivea Men Deodorant Invisible For Black & Whit...      16000       27300
# 2    Nivea Men Deodorant Invisible for Black & Whit...      44300       45100
# 3     Nivea Men Deodorant Silver Protect Roll On 25 ml      10700       12400
# 4     Nivea Men Deodorant Silver Protect Roll On 50 ml      14900       22400
# ..                                                 ...        ...         ...
# 115                               Trosyd 1% Cream 20 g     115500      174300
# 116                                 Tuderm N Cream 5 g       8600       23600
# 117                               Vaseline Putih 100 g      14400       27600
# 118                               Visancort Cream 10 g      10000       32500
# 119                             Zeliris 20% Cream 10 g      32500       65600
#
#     selling_unit            packaging  \
# 0      Per Botol       Botol @ 150 ml
# 1      Per Botol        Botol @ 50 ml
# 2      Per Botol       Botol @ 150 ml
# 3      Per Botol        Botol @ 25 ml
# 4      Per Botol        Botol @ 50 ml
# ..           ...                  ...
# 115     Per Tube        Tube 20 G X 1
# 116     Per Tube   Dus, Tube @ 5 gram
# 117    Per Botol          Pot @ 100 g
# 118     Per Tube    Dus, Tube @ 10 G
# 119     Per Tube  Tube 10 G Dalam Dus
#
#                                               kategori  \
# 0    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 1    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 2    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 3    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# 4    [{'external_id': '18c3b9e5-4425-404d-9368-d496...
# ..                                                 ...
# 115  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
# 116  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
# 117  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
# 118  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
# 119  [{'external_id': 'c018d44f-cbad-4729-a285-c33a...
#
#                                              deskripsi  \
# 0
# 1    NIVEA MEN DEODORANT INVISIBLE FOR BLACK&WHITE ...
# 2
# 3
# 4
# ..                                                 ...
# 115                                                  -
# 116
# 117
# 118  VISANCORT CREAM 10 G adalah obat yang digunaka...
# 119
#
#                                          indikasi_umum  \
# 0
# 1         Perlindungan terhadap keringat dan bau badan
# 2
# 3
# 4    Deodorant yang membantu mencegah bakteri penye...
# ..                                                 ...
# 115  Infeksi kulit yang disebabkan oleh jamur yang ...
# 116
# 117
# 118  Dermatitis Kontak atau Atopik, Dermatitis Ekze...
# 119                              Jerawat/akne vulgaris
#
#                                              komposisi  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 115                                     Tioconazole 1%
# 116  Betamethasone valerate 0.1%, dan neomycin sulp...
# 117
# 118  Hydrocortisone 10 mg, Cliquinol 10 mg, Camphor...
# 119                                   Azelaic acid 20%
#
#                                                  dosis  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 115  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 116                                                NaN
# 117                                   Sesuai kebutuhan
# 118  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 119  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
#
#                                           aturan_pakai  \
# 0
# 1                Oleskan secukupnya pada bagian ketiak
# 2
# 3
# 4    Aplikasikan secara merata pada ketiak. Biarkan...
# ..                                                 ...
# 115   Krim dioleskan pada bagian kulit yang terinfeksi
# 116
# 117
# 118  Krim dioleskan pada kulit yang sakit/radang/gatal
# 119
#
#                                        kontra_indikasi  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 115                    Hipersensitif terhadap imidazol
# 116
# 117
# 118  Penyakit virus dan TB kulit, akne vugaris, ska...
# 119
#
#                                              perhatian  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 115  HARUS DENGAN RESEP DOKTER. \nJangan digunakan ...
# 116
# 117
# 118  HARUS DENGAN RESEP DOKTER. \nPenggunaan jangka...
# 119  HARUS DENGAN RESEP DOKTER. \nHindari kontak de...
#
#                                           efek_samping         segmentasi  \
# 0                                                       (Consumer Goods,)
# 1                                                       (Consumer Goods,)
# 2                                                       (Consumer Goods,)
# 3                                                       (Consumer Goods,)
# 4                                                       (Consumer Goods,)
# ..                                                 ...                ...
# 115                                      Iritasi lokal             (Red,)
# 116                                                                (Red,)
# 117                                                     (Consumer Goods,)
# 118  Kulit kering, pruritus, iritasi, terbakar. Atr...             (Red,)
# 119                           Iritasi lokal pada kulit             (Red,)
#
#                manufaktur          no_registrasi  \
# 0    Beiersdorf Indonesia                    NaN
# 1    Beiersdorf Indonesia   BPOM:  NA49180900039
# 2    Beiersdorf Indonesia                    NaN
# 3    Beiersdorf Indonesia                    NaN
# 4    Beiersdorf Indonesia
# ..                    ...                    ...
# 115                Pfizer  BPOM: DKL8519800729A1
# 116             Meprofarm  BPOM: DKL0015614929A1
# 117              Unilever                    NaN
# 118         Caprifarmindo  BPOM: DKL7822251529A1
# 119         Caprifarmindo  BPOM: DKL9622218329A1
#
#                                                   slug  \
# 0        nivea-men-deodorant-fresh-active-spray-150-ml
# 1    nivea-men-deodorant-invisible-for-black-dan-wh...
# 2    nivea-men-deodorant-invisible-for-black-dan-wh...
# 3     nivea-men-deodorant-silver-protect-roll-on-25-ml
# 4     nivea-men-deodorant-silver-protect-roll-on-50-ml
# ..                                                 ...
# 115                                trosyd-1-cream-20-g
# 116                                 tuderm-n-cream-5-g
# 117                               vaseline-putih-100-g
# 118                               visancort-cream-10-g
# 119                              zeliris-20-cream-10-g
#
#                                 ProductID
# 0    fe9abe79-3bb4-40d4-bab6-f883665abd19
# 1    7bad509d-6d52-47cf-8171-cf0532452a32
# 2    3037f1f8-de0e-4de4-8ca8-6458597afeeb
# 3    44b82775-ee47-4c42-9793-799748d7ab80
# 4    736dced6-1ac1-47cb-9369-0a583c3accea
# ..                                    ...
# 115  1bccc015-81b1-4378-be7c-e70faad6aeed
# 116  50782b07-8b0f-4cb1-88a8-65f896bcf15a
# 117  d1542fd8-0037-43fe-bd52-a3460b5014c4
# 118  d12f754b-25ae-4c2b-9a2e-93f585301f7a
# 119  739f972b-4e20-4546-a957-ccb922b92db5
#
# [780 rows x 19 columns]

# %%
# export batukflu1
# result40_1.to_excel('crawling_scraping40_1.xlsx', index=False)
# result40_1_2.to_excel('crawling_scraping40_2.xlsx', index=False)

# %% [markdown]
# <br>
