# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Scraping No.5.2**
# > 30 - 40 categories

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "saluran-pencernaan"

page=20
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_pencernaan1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                               "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                               "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                               "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "saluran-pencernaan"

page=30
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_pencernaan2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                               "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                               "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                               "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "saluran-pencernaan"

page=30
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_pencernaan3 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                               "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                               "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                               "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_pencernaan1
# df_pencernaan2
df_pencernaan3
# Out:
#                                Nama  min_price  base_price selling_unit  \
# 0              Vomistop Drops 10 ml      43000       65700    Per Botol
# 1              Vomistop Sirup 60 ml      32000       64100    Per Botol
# 2               Vomitas Sirup 60 ml      47800       72000    Per Botol
# 3              Vomitrol Sirup 30 ml       4600        9800    Per Botol
# 4          Vomizole 20 mg 10 Tablet     161700      200000    Per Strip
# ..                              ...        ...         ...          ...
# 175              Zidiar Sirup 60 ml      27100       30000    Per Botol
# 176            Zircum Kid 10 Tablet      21100       21100    Per Strip
# 177  Zircum Kid Sirup 20mg/5ml 60ml      22200       50200    Per Botol
# 178         Zolacap 20 mg 10 Kapsul     104000      197800    Per Strip
# 179           Zollocid Kapsul 20 mg      14300       18000   Per Kapsul
#
#                                     packaging  \
# 0                        Dus, 1 botol @ 10 ml
# 1                          Dus, Botol @ 60 ml
# 2                          Dus, Botol @ 60 ml
# 3                          Dus, Botol @ 30 mL
# 4    Dus, 1 Blister @ 10 Tablet Salut Selaput
# ..                                        ...
# 175
# 176                  Dsu, 3 strip @ q0 tablet
# 177                           Botol 60 ml x 1
# 178                   Dus, 2 Strip @ 2 Kapsul
# 179
#
#                                               kategori deskripsi  \
# 0    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...         -
# 1    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...         -
# 2    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...         -
# 3    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...         -
# 4    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# ..                                                 ...       ...
# 175  [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# 176  [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# 177  [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# 178  [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...         -
# 179  [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
#
#                                          indikasi_umum  \
# 0    Anak2 : Mual & Muntah akibat kemoterapi & radi...
# 1    Anak2 : Mual & Muntah akibat kemoterapi & radi...
# 2    Mual & Muntah akibat kemoterapi & radioterapi ...
# 3    Keterlambatan pengosongan lambung/Gastroparesi...
# 4
# ..                                                 ...
# 175
# 176  Suplemen selama diare, diberikan bersama denga...
# 177  Suplemen selama diare, diberikan bersama denga...
# 178  Terapi jangka pendek untuk tukak lambung,tukak...
# 179
#
#                                komposisi  \
# 0    Per ml mengandung: Domperidone 5 mg
# 1            Per 5 mL : Domperidone 5 mg
# 2            Per 5 mL : Domperidone 5 mg
# 3         Per 5 mL : Metoclopramide 5 mg
# 4              Pantoprazole Sodium 20 mg
# ..                                   ...
# 175                         Zinc Sulfate
# 176                         Zinc Sulfate
# 177             Zn sulphate monohydrate.
# 178                     Omeprazole 20 mg
# 179                     Omeprazole 20 mg
#
#                                                  dosis  \
# 0    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 1    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 2    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 3    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 4                                                  NaN
# ..                                                 ...
# 175
# 176                                                NaN
# 177  Anak 6 bulan - 5 tahun : 1 sendok teh (5 ml) s...
# 178  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 179  PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
#
#                        aturan_pakai  \
# 0         15-30 menit sebelum makan
# 1         15-30 menit sebelum makan
# 2         15-30 menit sebelum makan
# 3            30 menit sebelum makan
# 4
# ..                              ...
# 175
# 176                 Sesudah makan\n
# 177                   Sesudah makan
# 178  Diberikan segera sebelum makan
# 179
#
#                                        kontra_indikasi  \
# 0    Pasien dengan tumor hipofise yang melepaskan p...
# 1    Pasien dengan tumor hipofise yang melepaskan p...
# 2                      Tumor hipofisis :  prolaktinoma
# 3    Feokromositoma, epilepsi, obstruksi intestinal...
# 4
# ..                                                 ...
# 175
# 176
# 177
# 178                                                  -
# 179
#
#                                              perhatian  \
# 0    HARUS DENGAN RESEP DOKTER. \nGangguan hati dan...
# 1    HARUS DENGAN RESEP DOKTER. \nGangguan hati dan...
# 2    HARUS DENGAN RESEP DOKTER. \nGangguan hati dan...
# 3    HARUS DENGAN RESEP DOKTER. \nDiabetes, depresi...
# 4
# ..                                                 ...
# 175
# 176
# 177
# 178  HARUS DENGAN RESEP DOKTER. \nAnak, hamil, lakt...
# 179                        HARUS DENGAN RESEP DOKTER.
#
#                                           efek_samping segmentasi  \
# 0    Galaktore, ginekomastia, gatal, sakit kepala, ...     (Red,)
# 1    Galaktore, ginekomastia, gatal, sakit kepala, ...     (Red,)
# 2    Galaktore, ginekomastia, gatal, sakit kepala, ...     (Red,)
# 3    Mengantuk, depresi, sakit kepala, gejala ekstr...     (Red,)
# 4                                                          (Red,)
# ..                                                 ...        ...
# 175                                                       (Blue,)
# 176  Toksisitas zinc, penurunan kadar lipoprotein p...    (Blue,)
# 177  Toksisitas zinc, penurunan kadar lipoprotein p...    (Blue,)
# 178  Pertumbuhan sel EGL(penggunaan jangka panjang ...     (Red,)
# 179                                                        (Red,)
#
#                   manufaktur          no_registrasi  \
# 0           Gracia Pharmindo  BPOM: DKL0835306436A1
# 1           Gracia Pharmindo  BPOM: DKL0935306633A1
# 2                Kalbe Farma  BPOM: DKL0211634537A1
# 3                     Pharos  BPOM: DKL8321601837A1
# 4                Dexa Medica  BPOM: DKL1505051215A1
# ..                       ...                    ...
# 175       Tempo Scan Pacific  BPOM: DTL0922720637A1
# 176                Meprofarm  BPOM: DTL1815626781A1
# 177                Meprofarm  BPOM: DTL1115621237A1
# 178            Caprifarmindo  BPOM: DKL0832401503A1
# 179  Pertiwi Agung (Landson)  BPOM: DKL1919621403A1
#
#                                slug                             ProductID
# 0              vomistop-drops-10-ml  f21478ec-66ea-43ff-946d-a1bd2d8219e2
# 1              vomistop-sirup-60-ml  5cc21501-4bfa-4f43-b89b-f2141d61ae4b
# 2               vomitas-sirup-60-ml  296c6bb9-b244-4a8e-b39a-fda7b78d9d12
# 3              vomitrol-sirup-30-ml  0df96686-4267-4304-ab9c-d99c55ca0866
# 4          vomizole-20-mg-10-tablet  8185c2ae-a5c9-4d8e-bcd3-8fad11068c7b
# ..                              ...                                   ...
# 175              zidiar-sirup-60-ml  86f4fcd7-fe40-4e2a-a7d9-78319dc3c3b7
# 176            zircum-kid-10-tablet  87cff6d0-f8ab-496d-bd16-c3afc94432a9
# 177  zircum-kid-sirup-20mg-5ml-60ml  2cb10631-c8a8-4e6c-b867-b24270f1967c
# 178         zolacap-20-mg-10-kapsul  2bd1dd28-1e94-41c6-a231-0d1f5cd13308
# 179           zollocid-kapsul-20-mg  fb95ae78-b78c-4f6e-914c-963533bd2e66
#
# [180 rows x 19 columns]

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "lensa-kontak"

page=20
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_lensa1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                               "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                               "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                               "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "lensa-kontak"

page=30
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_lensa2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                               "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                               "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                               "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "lensa-kontak"

page=34
for i in range(30,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_lensa3 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                               "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                               "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                               "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_lensa1
# df_lensa2
df_lensa3
# Out:
#                                                  Nama  min_price  base_price  \
# 0             X2 New Diva Grey 2 Color Softlens Minus      50400      100800
# 1    X2 New Diva Grey 2 Color Softlens Plano/No Minus      50400      100800
# 2           X2 Sanso Cappucino 2 Color Softlens Minus      67200      134400
# 3   X2 Sanso Cappucino 2 Color Softlens Plano/No M...      67200      134400
# 4               X2 Sanso Clear 3 Clear Softlens Minus      88500      280000
# ..                                                ...        ...         ...
# 75           X2 Sanso Radiance 2 Color Softlens Minus      67200      134400
# 76  X2 Sanso Radiance 2 Color Softlens Plano/No Minus      67200      134400
# 77             X2 Sanso Shadow 2 Color Softlens Minus      67200      134400
# 78    X2 Sanso Shadow 2 Color Softlens Plano/No Minus      67200      134400
# 79         X2 Seduction Claudy 2 Color Softlens Minus          0           0
#
#             selling_unit                    packaging  \
# 0     Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
# 1     Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
# 2     Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
# 3     Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
# 4   Per Box (1.5 Pasang)  Box @ 3 Soft Contact Lense.
# ..                   ...                          ...
# 75    Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
# 76    Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
# 77    Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
# 78    Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
# 79    Per Box (1 Pasang)  Box @ 2 Soft Contact Lense.
#
#                                              kategori  \
# 0   [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# 1   [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# 2   [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# 3   [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# 4   [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# ..                                                ...
# 75  [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# 76  [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# 77  [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# 78  [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
# 79  [{'external_id': '81ce8240-aefb-49df-81ad-1d7b...
#
#                                             deskripsi  \
# 0   Softlense X2 NEW DIVA merupakan softlense deng...
# 1   Softlense X2 NEW DIVA merupakan softlense deng...
# 2   Softlense X2 Sanso merupakan softlense untuk p...
# 3   Softlense X2 Sanso merupakan softlense untuk p...
# 4   Softlens SANSO CLEAR merupakan softlense denga...
# ..                                                ...
# 75  Softlense X2 Sanso merupakan softlense untuk p...
# 76  Softlense X2 Sanso merupakan softlense untuk p...
# 77  Softlense X2 Sanso merupakan softlense untuk p...
# 78  Softlense X2 Sanso merupakan softlense untuk p...
# 79  Softlens X2 SEDUCTION merupakan Softlens denga...
#
#                                         indikasi_umum  \
# 0   Softlens X2 NEW DIVA untuk penggunaan 6 Bulan....
# 1   Softlens X2 NEW DIVA untuk penggunaan 6 Bulan....
# 2   Softlens Minus X2 Sanso untuk penggunaan 6 Bul...
# 3   Softlense X2 Sanso untuk penggunaan 6 Bulan. \...
# 4   Softlens X2 SANSO CLEAR untuk penggunaan 1 Bul...
# ..                                                ...
# 75  Softlens Minus X2 Sanso untuk penggunaan 6 Bul...
# 76  Softlense X2 Sanso untuk penggunaan 6 Bulan. \...
# 77  Softlens Minus X2 Sanso untuk penggunaan 6 Bul...
# 78  Softlense X2 Sanso untuk penggunaan 6 Bulan. \...
# 79  Softlens X2 SEDUCTION untuk penggunaan 6 Bulan...
#
#                                        komposisi dosis  \
# 0                42% Water Content, 58% Polyhema   NaN
# 1                42% Water Content, 58% Polyhema   NaN
# 2   Bahan/Material : Silicon Hydrogel, Water 55%   NaN
# 3   Bahan/Material : Silicon Hydrogel, Water 55%   NaN
# 4                              56% Water Content   NaN
# ..                                           ...   ...
# 75  Bahan/Material : Silicon Hydrogel, Water 55%   NaN
# 76  Bahan/Material : Silicon Hydrogel, Water 55%   NaN
# 77  Bahan/Material : Silicon Hydrogel, Water 55%   NaN
# 78  Bahan/Material : Silicon Hydrogel, Water 55%   NaN
# 79               42% Water Content, 58% Polyhema   NaN
#
#                                          aturan_pakai kontra_indikasi  \
# 0   Bersihkan tangan sebelum menggunakan softlens....
# 1   Bersihkan tangan sebelum menggunakan softlens....
# 2   Bersihkan tangan sebelum menggunakan softlens....
# 3   Bersihkan tangan sebelum menggunakan softlens....
# 4   Bersihkan tangan sebelum menggunakan softlens....
# ..                                                ...             ...
# 75  Bersihkan tangan sebelum menggunakan softlens....
# 76  Bersihkan tangan sebelum menggunakan softlens....
# 77  Bersihkan tangan sebelum menggunakan softlens....
# 78  Bersihkan tangan sebelum menggunakan softlens....
# 79  Bersihkan tangan sebelum menggunakan softlens....
#
#                                             perhatian efek_samping  \
# 0   Dalam pembelian produk ini, mohon dicantumkan ...
# 1   Softlens ini merupakan softlense warna Plano/N...
# 2   Produk ini merupakan Softlens Minus yang dituj...
# 3   Produk ini merupakan Softlens Plano atau No Mi...
# 4   Dalam pembelian produk ini, mohon dicantumkan ...
# ..                                                ...          ...
# 75  Produk ini merupakan Softlens Minus yang dituj...
# 76  Produk ini merupakan Softlens Plano atau No Mi...
# 77  Produk ini merupakan Softlens Minus yang dituj...
# 78  Produk ini merupakan Softlens Plano atau No Mi...
# 79  Dalam pembelian produk ini, mohon dicantumkan ...
#
#                         segmentasi manufaktur                no_registrasi  \
# 0   (Medical Device & Consumable,)   Katamata
# 1   (Medical Device & Consumable,)   Katamata  Kemenkes RI: AKL21204718097
# 2   (Medical Device & Consumable,)       None
# 3   (Medical Device & Consumable,)   Exoticon  Kemenkes RI: AKL21204710932
# 4   (Medical Device & Consumable,)   Katamata
# ..                             ...        ...                          ...
# 75  (Medical Device & Consumable,)       None
# 76  (Medical Device & Consumable,)       None
# 77  (Medical Device & Consumable,)       None
# 78  (Medical Device & Consumable,)   Exoticon  Kemenkes RI: AKL21204710932
# 79  (Medical Device & Consumable,)   Katamata  Kemenkes RI: AKL21204712649
#
#                                                  slug  \
# 0             x2-new-diva-grey-2-color-softlens-minus
# 1    x2-new-diva-grey-2-color-softlens-plano-no-minus
# 2           x2-sanso-cappucino-2-color-softlens-minus
# 3   x2-sanso-cappucino-2-color-softlens-plano-no-m...
# 4               x2-sanso-clear-3-clear-softlens-minus
# ..                                                ...
# 75           x2-sanso-radiance-2-color-softlens-minus
# 76  x2-sanso-radiance-2-color-softlens-plano-no-minus
# 77             x2-sanso-shadow-2-color-softlens-minus
# 78    x2-sanso-shadow-2-color-softlens-plano-no-minus
# 79         x2-seduction-claudy-2-color-softlens-minus
#
#                                ProductID
# 0   dbef2fd8-81ed-4b46-a403-5c41d74b5b74
# 1   504012b0-b98a-4a97-85bb-f9f35750a611
# 2   bf88d140-f32d-4b86-bd60-2c5da346caf0
# 3   effaed81-dcba-45f8-9e21-6f275361f929
# 4   5519c7bd-7c33-4998-95c7-aa676f102f0d
# ..                                   ...
# 75  138899de-3e9b-4c48-bcac-2f64b25da92e
# 76  817911e0-e0d3-43c4-9137-68eb59cc6234
# 77  68b7c469-46fb-4e07-8c3b-bf8e6ab311b2
# 78  7ddbae4b-d1ed-4305-b7c0-20bc924d7847
# 79  231f2724-4dac-4b52-a045-e45fbfc98c2f
#
# [80 rows x 19 columns]

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}


page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "herbal"

page=20
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_herbal1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "herbal"

page=40
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_herbal2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "herbal"

page=48
for i in range(40,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_herbal3 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_herbal1
# df_herbal2
df_herbal3
# Out:
#                                  Nama  min_price  base_price selling_unit  \
# 0                     Uricid 4 Kapsul       8400        8900    Per Strip
# 1                    Valbum 10 Kapsul      74600       75000    Per Strip
# 2                   Vastral 10 Kaplet        600      255200    Per Strip
# 3                    Vedium 10 Kaplet      65300       76000    Per Strip
# 4                   Vegamon 10 Kapsul      66000       72400    Per Strip
# ..                                ...        ...         ...          ...
# 155  Virgin Coconut Oil Cocona 300 ml      85400      126000    Per Botol
# 156  Virgin Coconut Oil Vicoma 120 ml      27100       52800    Per Botol
# 157  Virgin Coconut Oil Wonder 125 ml      32400       59400    Per Botol
# 158             Virgin Natural 100 ml      25200       42700    Per Botol
# 159   Virjint Super Coconut Oil 80 ml      23800       63800    Per Botol
#
#                                  packaging  \
# 0    Dus, 20 catch cover, strip @ 4 kapsul
# 1              Box @ 6 Blister @ 10 Kapsul
# 2                Dus, 10 Strip @ 10 Kaplet
# 3                 Dus, 3 Strip @ 10 Kaplet
# 4
# ..                                     ...
# 155                        Botol, @ 370 ml
# 156                       Botol 120 ml X 1
# 157                         Botol @ 125 ml
# 158                         Botol @ 100 ml
# 159                          Botol @ 80 ml
#
#                                               kategori  \
# 0    [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# 1    [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# 2    [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# 3    [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# 4    [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# ..                                                 ...
# 155  [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# 156  [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# 157  [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# 158  [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
# 159  [{'external_id': 'e393fd86-2160-4de0-aaca-c1b8...
#
#                                              deskripsi  \
# 0    URICID PIL merupakan obat jamu herbal tradisio...
# 1    VALBUM KAPSUL merupakan suplemen makanan yang ...
# 2
# 3
# 4
# ..                                                 ...
# 155  VIRGIN COCONUT OIL COCONA 370 ML di buat dari ...
# 156
# 157
# 158
# 159
#
#                                          indikasi_umum  \
# 0    Membantu meredakan pegal linu dan nyeri pada p...
# 1    Untuk memelihara kesehatan tubuh, membantu men...
# 2
# 3                    Membantu meringankan gejala wasir
# 4
# ..                                                 ...
# 155
# 156
# 157
# 158
# 159  Membantu mengatasi penyakit diabetes,Anti viru...
#
#                                              komposisi  \
# 0    Celery seed extract (biji seledri) 60 mg, Curc...
# 1    Tiap kapsul mengandung: Ophiocepalus striatus ...
# 2
# 3    Micronised purified flavonoid fraction yang se...
# 4
# ..                                                 ...
# 155
# 156
# 157  100 % Virgin Coconut Oil (Kelapa Pilihan), Pandan
# 158  100 % Virgin Coconut Oil (Kelapa Pilihan), Pandan
# 159  Virgin Coconut Oil (minyak kelapa murni) 500 m...
#
#                                                  dosis  \
# 0                    1 kapsul, diminum 2 kali per hari
# 1                                3 x Sehari 1-3 Kapsul
# 2                                                  NaN
# 3                              2 kali sehari 1 kaplet.
# 4                                                  NaN
# ..                                                 ...
# 155
# 156                                   Sesuai kebutuhan
# 157
# 158
# 159  Pengobatan : 3 x 1 sendok makan,Pencegahan : 1...
#
#                              aturan_pakai kontra_indikasi perhatian  \
# 0                Dikonsumsi setelah makan
# 1                           Sesudah makan
# 2
# 3                                           Hipersensitif   Laktasi
# 4
# ..                                    ...             ...       ...
# 155
# 156
# 157
# 158
# 159  Diminum sebeblum atau sesudah makan
#
#     efek_samping         segmentasi                  manufaktur  \
# 0                         (Herbal,)               Dami Sariwana
# 1                         (Herbal,)           Midix Graha Farma
# 2                         (Herbal,)                  Novapharin
# 3    Gangguan GI          (Herbal,)  Medikon Prima Laboratories
# 4                         (Herbal,)              Solas Langgeng
# ..           ...                ...                         ...
# 155               (Consumer Goods,)                        None
# 156               (Consumer Goods,)  Anugerah Mas Internasional
# 157               (Consumer Goods,)                Wonder Herbs
# 158               (Consumer Goods,)                        None
# 159               (Consumer Goods,)           Sukses Abadi Raya
#
#          no_registrasi                              slug  \
# 0    BPOM: TR173309531                   uricid-4-kapsul
# 1    BPOM: TR192325091                  valbum-10-kapsul
# 2    BPOM: SD071530041                 vastral-10-kaplet
# 3    BPOM: TR182522221                  vedium-10-kaplet
# 4                                      vegamon-10-kapsul
# ..                 ...                               ...
# 155                NaN  virgin-coconut-oil-cocona-300-ml
# 156                NaN  virgin-coconut-oil-vicoma-120-ml
# 157                NaN  virgin-coconut-oil-wonder-125-ml
# 158                NaN             virgin-natural-100-ml
# 159                NaN   virjint-super-coconut-oil-80-ml
#
#                                 ProductID
# 0    1ced1085-a623-4255-87d9-6d16631ef822
# 1    85856bbb-3165-43ca-9d23-95ff8222454e
# 2    6d014c13-6285-4662-94c9-f92ab3ec997f
# 3    7fb33837-51d5-498c-a77e-2159da6a1366
# 4    41778baa-70b8-4c2a-a9b7-493d3b7e4308
# ..                                    ...
# 155  a05a1e68-0a55-4674-941c-cc02a0bd53ef
# 156  87c80edc-a526-403d-9af6-1ed65ff4242b
# 157  52d0d326-0b19-4f11-b058-562b3742cac6
# 158  60ecdc49-cc83-4cb8-937c-49d2e4652ed7
# 159  3765bf41-7d09-4bd2-ac22-6f27b2f55e93
#
# [160 rows x 19 columns]

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "perawatan-hewan"

page=20
for i in range(0,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_hewan1 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "perawatan-hewan"

page=40
for i in range(20,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_hewan2 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "perawatan-hewan"

page=60
for i in range(40,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_hewan3 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
from urllib.request import Request, urlopen
import json
from bs4 import BeautifulSoup
import pandas as pd
import requests


categories = []
url = "https://www.halodoc.com/obat-dan-vitamin"
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
product_category = soup.findAll("img",attrs={'loading':'lazy'})
for kategori in product_category:
    if (len(kategori["title"])>0):
        categories.append(kategori["title"])

#ARRAY
nama_obat = []
min_harga = []
base_harga = []
sell_unit = []
paking_obat = []
kategori_obat = []
deskripsi_obat = []
indikasi_obat = []
komposisi_obat = []
dosis_obat = []
aturan_pakai_obat = []
kontra_indikasi_obat = []
perhatian_obat = []
efek_samping_obat = []
segmentasi_obat = []
manufaktur_obat = []
no_registrasi_obat = []
slug_obat = []
id_produk = []


infinite_looper = 1
page = 0
# for i in range(18,25):

categories_url = "perawatan-hewan"

page=78
for i in range(60,page):
  main_url = "https://www.halodoc.com/api/v1/buy-medicine/categories/" + categories_url
  second_url = "/products?page=%d&size=20" % page
  url = main_url+second_url
  status_code = requests.get(url).status_code
  if (status_code != 404):
      req = Request(url, headers={'User-Agent': 'XYZ/3.0'})
      webpage = urlopen(req, timeout=10).read()
      json_data = webpage.decode('utf-8')
      full_data = json.loads(json_data)
      result = full_data["result"]
      
      obatlist = []
      for i in range (0,len(result)):
          slug = result[i]["slug"]
          new_url="https://www.halodoc.com/api/v1/buy-medicine/products/detail/"
          new_url_slug = new_url+slug
          request=urlopen(new_url_slug)
          json_data = request.read().decode('utf-8')
          full_data = json.loads(json_data)

          nama = full_data["name"]
          if 'base_price' in full_data:
              min_price = full_data["min_price"]
          else:
              min_price = "NaN"
          if 'base_price' in full_data:
              base_price = full_data["base_price"]
          else:
              base_price = "NaN"
          if 'selling_unit' in full_data:
              selling_unit = full_data["selling_unit"]
          else:
              selling_unit = "NaN"
          if 'packaging' in full_data:
              packaging = full_data["packaging"]
          else:
              packaging = "NaN"
          if 'description' in full_data:
            deskripsi = full_data["description"]
          else:
            deskripsi = "NaN"
          if 'general_indication' in full_data:
              indikasi_umum = full_data["general_indication"]
          else:
              indikasi_umum = "NaN"
          if 'composition' in full_data:
              komposisi = full_data["composition"]
          else:
              komposisi = "NaN"
          if 'dosage' in full_data:
              dosis = full_data["dosage"]
          else:
              dosis = "NaN"
          if 'how_to_use' in full_data:
              aturan_pakai = full_data["how_to_use"]
          else:
              aturan_pakai = "NaN"
          if 'contraindication' in full_data:
              kontra_indikasi = full_data["contraindication"]
          else:
              kontra_indikasi = "NaN"
          if 'warning' in full_data:
              perhatian = full_data["warning"]
          else:
              perhatian = "NaN"
          if 'side_effects' in full_data:
              efek_samping = full_data["side_effects"]
          else:
              efek_samping = "NaN"
          if 'segmentation' in full_data:
              segmentasi = full_data["segmentation"],
          else:
              segmentasi = "NaN"
          if 'manufacturer_name' in full_data:
              manufaktur = full_data["manufacturer_name"]
          else:
              manufaktur = "NaN"
          if 'bpom_number' in full_data:
            no_registrasi = full_data["bpom_number"]
          else:
            no_registrasi = "NaN"

          slug = full_data["canon_slug"]
          productID = full_data["external_id"]
          
          # Test Print
          # print(i)
          # print(nama)
          # print(min_price)
          # print(base_price)
          # print(manufaktur)
          
          kategori = full_data["categories"]
          for i in range (0,len(kategori)):
              kategori_produk = kategori[i]["name"]
          
          nama_obat.append(nama)
          min_harga.append(min_price)
          base_harga.append(base_price)
          sell_unit.append(selling_unit)
          paking_obat.append(packaging)
          kategori_obat.append(kategori)
          deskripsi_obat.append(deskripsi)
          indikasi_obat.append(indikasi_umum)
          komposisi_obat.append(komposisi)
          dosis_obat.append(dosis)
          aturan_pakai_obat.append(aturan_pakai)
          kontra_indikasi_obat.append(kontra_indikasi)
          perhatian_obat.append(perhatian)
          efek_samping_obat.append(efek_samping)
          segmentasi_obat.append(segmentasi)
          manufaktur_obat.append(manufaktur)
          no_registrasi_obat.append(no_registrasi)
          slug_obat.append(slug)
          id_produk.append(productID)

  else:
      break

df_hewan4 = pd.DataFrame({"Nama":nama_obat,"min_price":min_harga,"base_price":base_harga,"selling_unit":sell_unit,"packaging":paking_obat,
                          "kategori":kategori_obat,"deskripsi":deskripsi_obat,"indikasi_umum":indikasi_obat,"komposisi":komposisi_obat,"dosis":dosis_obat,
                          "aturan_pakai":aturan_pakai_obat,"kontra_indikasi":kontra_indikasi_obat,"perhatian":perhatian_obat,"efek_samping":efek_samping_obat,"segmentasi":segmentasi_obat,
                          "manufaktur":manufaktur_obat,"no_registrasi":no_registrasi_obat,"slug":slug_obat,"ProductID":id_produk})

# %%
# df_hewan1
# df_hewan2
# df_hewan3
df_hewan4
# Out:
#                                                   Nama  min_price  base_price  \
# 0                Whiskas Junior Rasa Mackerel Wet 85 g       6800       10700
# 1            Whiskas Junior Rasa Ocean Fish Dry 1.1 kg      66400       84000
# 2             Whiskas Junior Rasa Ocean Fish Dry 450 g      28800       39200
# 3                    Whiskas Junior Rasa Tuna Wet 85 g       6400     1039500
# 4    Whiskas Senior Cat 7+ Years Mackerel Flavor 1....      61300       77800
# ..                                                 ...        ...         ...
# 157  Whiskas Senior Cat 7+ Years Mackerel Flavor 1....      61300       77800
# 158   Whiskas Senior Cat 7+ Years Mackerel Flavor 85 g       6300        9000
# 159       Whiskas Senior Cat 7+ Years Tuna Flavor 85 g       6300        7900
# 160  Yummy Hair & Skin Support Tuna Red Meat In Jel...      18700       21400
# 161  Yummy Hair & Skin Support Tuna Shrimp For Kitt...      18200       20200
#
#     selling_unit       packaging  \
# 0      Per Pouch    Pouch @ 85 G
# 1       Per Pack   Pack @ 1,1 Kg
# 2       Per Pack    Pack @ 450 G
# 3      Per Pouch    Pouch @ 85 G
# 4       Per Pack   Pack @ 1,1 kg
# ..           ...             ...
# 157     Per Pack   Pack @ 1,1 kg
# 158    Per Pouch    Pouch @ 85 G
# 159    Per Pouch    Pouch @ 85 G
# 160   Per Kaleng  Kaleng @ 400 g
# 161   Per Kaleng  Kaleng @ 400 G
#
#                                               kategori  \
# 0    [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 1    [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 2    [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 3    [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 4    [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# ..                                                 ...
# 157  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 158  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 159  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 160  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 161  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
#
#                                              deskripsi  \
# 0    WHISKAS JUNIOR RASA MACKEREL merupakan makanan...
# 1    WHISKAS JUNIOR RASA OCEAN FISH merupakan makan...
# 2    WHISKAS JUNIOR RASA OCEAN FISH merupakan makan...
# 3    WHISKAS JUNIOR RASA TUNA merupakan makanan khu...
# 4
# ..                                                 ...
# 157
# 158
# 159
# 160
# 161  YUMMY HAIR & SKIN SUPPORT TUNA SHRIMP FOR KITT...
#
#                                          indikasi_umum  \
# 0    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Sebag...
# 1    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Sebag...
# 2    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Sebag...
# 3    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Sebag...
# 4             PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# ..                                                 ...
# 157           PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# 158           PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# 159           PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# 160  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. \nMak...
# 161  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Sebag...
#
#                                              komposisi dosis aturan_pakai  \
# 0                                                        NaN
# 1    Seluruh Grain sereal (jagung, padi), gluten te...   NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# ..                                                 ...   ...          ...
# 157                                                      NaN
# 158                                                      NaN
# 159                                                      NaN
# 160                                                      NaN
# 161                                                      NaN
#
#     kontra_indikasi                                          perhatian  \
# 0                    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Jauhk...
# 1                    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Jauhk...
# 2                    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Jauhk...
# 3                    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Jauhk...
# 4                    PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Simpa...
# ..              ...                                                ...
# 157                  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Simpa...
# 158                  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Simpa...
# 159                  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Simpa...
# 160                           PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# 161                  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Jauhk...
#
#     efek_samping          segmentasi                    manufaktur  \
# 0                 (Animal Supplies,)  Mars Symbioscience Indonesia
# 1                 (Animal Supplies,)  Mars Symbioscience Indonesia
# 2                 (Animal Supplies,)  Mars Symbioscience Indonesia
# 3                 (Animal Supplies,)  Mars Symbioscience Indonesia
# 4                 (Animal Supplies,)  Mars Symbioscience Indonesia
# ..           ...                 ...                           ...
# 157               (Animal Supplies,)  Mars Symbioscience Indonesia
# 158               (Animal Supplies,)  Mars Symbioscience Indonesia
# 159               (Animal Supplies,)  Mars Symbioscience Indonesia
# 160               (Animal Supplies,)                          None
# 161               (Animal Supplies,)                          None
#
#     no_registrasi                                               slug  \
# 0                              whiskas-junior-rasa-mackerel-wet-85-g
# 1                          whiskas-junior-rasa-ocean-fish-dry-1-1-kg
# 2                           whiskas-junior-rasa-ocean-fish-dry-450-g
# 3                                  whiskas-junior-rasa-tuna-wet-85-g
# 4                  whiskas-senior-cat-7-years-mackerel-flavor-1-1-kg
# ..            ...                                                ...
# 157                whiskas-senior-cat-7-years-mackerel-flavor-1-1-kg
# 158                  whiskas-senior-cat-7-years-mackerel-flavor-85-g
# 159                      whiskas-senior-cat-7-years-tuna-flavor-85-g
# 160                yummy-hair-dan-skin-support-tuna-red-meat-in-j...
# 161                yummy-hair-dan-skin-support-tuna-shrimp-for-ki...
#
#                                 ProductID
# 0    89583392-dc92-4a6a-84e0-d01aa07bbe1f
# 1    fc969d85-fadc-4869-9616-aadcc1fb594b
# 2    e95830b4-b424-4240-aa6f-f032a15183a4
# 3    d07c03cd-299d-427f-83b4-e51442af67ff
# 4    77427c28-e374-45fa-8c32-c12741ff38a4
# ..                                    ...
# 157  77427c28-e374-45fa-8c32-c12741ff38a4
# 158  6232e794-1d81-44c3-abcb-731494cc4b56
# 159  507c8a64-0bbd-48c0-b6f0-7beabcb1b5a3
# 160  17d4dc1e-843f-4fbf-8432-dbbb021d88b8
# 161  f5b3082d-5fc0-41bf-bbd0-67adf8d5753c
#
# [162 rows x 19 columns]

# %%
frames = [df_pencernaan1,df_pencernaan2,df_pencernaan3,
          df_lensa1,df_lensa2,df_lensa3,
          df_herbal1,df_herbal2,df_herbal3,
          df_hewan1,df_hewan2,df_hewan3,df_hewan4]
        
result40_3 = pd.concat(frames)

# %%
result40_3
# Out:
#                                                   Nama  min_price  base_price  \
# 0                                Invitec 200 mg Tablet      10200       18800
# 1         Jamu Iboe Natural Drink Lidah Buaya 5 Sachet      12600       12600
# 2                      Kalpepsa 500 mg Suspensi 100 ml      39500       72000
# 3                                Kliran 4 mg 10 Kaplet     120700      186300
# 4                            Konvermex 250 mg 2 Kaplet       9400       25000
# ..                                                 ...        ...         ...
# 157  Whiskas Senior Cat 7+ Years Mackerel Flavor 1....      61300       77800
# 158   Whiskas Senior Cat 7+ Years Mackerel Flavor 85 g       6300        9000
# 159       Whiskas Senior Cat 7+ Years Tuna Flavor 85 g       6300        7900
# 160  Yummy Hair & Skin Support Tuna Red Meat In Jel...      18700       21400
# 161  Yummy Hair & Skin Support Tuna Shrimp For Kitt...      18200       20200
#
#     selling_unit                 packaging  \
# 0     Per Tablet  Dus, 3 Strip @ 10 Tablet
# 1        Per Box  Dus, 5 bungkus @ 25 gram
# 2      Per Botol       Dus, Botol @ 100 ml
# 3      Per Strip    Kaplet 4 Mg X 3 X 10\n
# 4      Per Strip        Strip Isi 2 Tablet
# ..           ...                       ...
# 157     Per Pack             Pack @ 1,1 kg
# 158    Per Pouch              Pouch @ 85 G
# 159    Per Pouch              Pouch @ 85 G
# 160   Per Kaleng            Kaleng @ 400 g
# 161   Per Kaleng            Kaleng @ 400 G
#
#                                               kategori  \
# 0    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# 1    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# 2    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# 3    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# 4    [{'external_id': 'c58ecdb3-d2df-4a1c-aa9f-b55f...
# ..                                                 ...
# 157  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 158  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 159  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 160  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
# 161  [{'external_id': 'ab49ff5d-1d63-4aaf-bf0d-906f...
#
#                                              deskripsi  \
# 0
# 1    JAMU IBOE NATURAL DRINK LIDAH BUAYA merupakan ...
# 2
# 3
# 4    KONVERMEX 250 MG KAPLET merupakan obat yang di...
# ..                                                 ...
# 157
# 158
# 159
# 160
# 161  YUMMY HAIR & SKIN SUPPORT TUNA SHRIMP FOR KITT...
#
#                                          indikasi_umum  \
# 0
# 1                 Membantu melancarkan buang air besar
# 2    INFORMASI OBAT INI HANYA UNTUK KALANGAN MEDIS....
# 3    Penatalaksanaan mual dan muntah yang diinduksi...
# 4                                          Antelmintik
# ..                                                 ...
# 157           PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# 158           PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# 159           PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# 160  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. \nMak...
# 161  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Sebag...
#
#                                    komposisi  \
# 0                         Misoprostol 200 mg
# 1
# 2    Tiap 5 ml mengandung: Sucralfate 500 mg
# 3                           Ondansetron 4 mg
# 4                      Pyrantel base 250 mg.
# ..                                       ...
# 157
# 158
# 159
# 160
# 161
#
#                                                  dosis  \
# 0                                                  NaN
# 1                             Diminum 1-3 kali sehari.
# 2
# 3    PENGGUNAAN OBAT INI HARUS SESUAI DENGAN PETUNJ...
# 4    Anak < 5 th : 1/2 tablet / hari; Anak 5-9 th :...
# ..                                                 ...
# 157                                                NaN
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
#
#                                           aturan_pakai kontra_indikasi  \
# 0
# 1    Seduh 1 bungkus Jamoe Ibu dengan air matang 15...
# 2
# 3
# 4                 Dosis tunggal, diminum sebelum tidur   Hipersensitif
# ..                                                 ...             ...
# 157
# 158
# 159
# 160
# 161
#
#                                              perhatian  \
# 0
# 1
# 2
# 3    HARUS DENGAN RESEP DOKTER. \nHamil dan laktasi...
# 4    Untuk infeksi cacing tambang, dianjurkan untuk...
# ..                                                 ...
# 157  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Simpa...
# 158  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Simpa...
# 159  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Simpa...
# 160           PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN.
# 161  PRODUK INI HANYA DIKONSUMSI UNTUK HEWAN. Jauhk...
#
#                                           efek_samping          segmentasi  \
# 0                                                                   (Red,)
# 1                                                                (Herbal,)
# 2                                                                   (Red,)
# 3    Sakit kepala, konstipasi, rasa panas dan terba...              (Red,)
# 4    Nafsu akan hilang, mual, muntah, diare, sakit ...             (Blue,)
# ..                                                 ...                 ...
# 157                                                     (Animal Supplies,)
# 158                                                     (Animal Supplies,)
# 159                                                     (Animal Supplies,)
# 160                                                     (Animal Supplies,)
# 161                                                     (Animal Supplies,)
#
#                        manufaktur          no_registrasi  \
# 0                    Dankos Farma  BPOM: DKL0504424610A1
# 1                  Jamu Iboe Jaya      BPOM: TR183219161
# 2                     Kalbe Farma  BPOM: DKL1211642333A1
# 3                       Bernofarm  BPOM: DKL9502321409B1
# 4                         Konimex  BPOM: DTL0413022204A1
# ..                            ...                    ...
# 157  Mars Symbioscience Indonesia
# 158  Mars Symbioscience Indonesia
# 159  Mars Symbioscience Indonesia
# 160                          None
# 161                          None
#
#                                                   slug  \
# 0                                invitec-200-mg-tablet
# 1         jamu-iboe-natural-drink-lidah-buaya-5-sachet
# 2                      kalpepsa-500-mg-suspensi-100-ml
# 3                                kliran-4-mg-10-kaplet
# 4                            konvermex-250-mg-2-kaplet
# ..                                                 ...
# 157  whiskas-senior-cat-7-years-mackerel-flavor-1-1-kg
# 158    whiskas-senior-cat-7-years-mackerel-flavor-85-g
# 159        whiskas-senior-cat-7-years-tuna-flavor-85-g
# 160  yummy-hair-dan-skin-support-tuna-red-meat-in-j...
# 161  yummy-hair-dan-skin-support-tuna-shrimp-for-ki...
#
#                                 ProductID
# 0    f018f5f5-d26f-45d7-857e-525c543d5c34
# 1    b2622371-641b-4f37-aeab-dd2e08ecb6b8
# 2    a24b775e-22a0-47e3-aa46-eae2774e3142
# 3    ba1620a0-6402-466a-b53e-899e3cf83079
# 4    52e54486-ebd2-4be1-9e29-b2ab34a30602
# ..                                    ...
# 157  77427c28-e374-45fa-8c32-c12741ff38a4
# 158  6232e794-1d81-44c3-abcb-731494cc4b56
# 159  507c8a64-0bbd-48c0-b6f0-7beabcb1b5a3
# 160  17d4dc1e-843f-4fbf-8432-dbbb021d88b8
# 161  f5b3082d-5fc0-41bf-bbd0-67adf8d5753c
#
# [3762 rows x 19 columns]

# %%
# export batukflu1
# result40_3.to_excel('crawling_scraping40_3.xlsx', index=False)
